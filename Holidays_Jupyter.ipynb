# %%
# import datetime
import datetime
# from datetime import datetime
# from datetime import date
import json
from bs4 import BeautifulSoup
import requests
from dataclasses import dataclass



# -------------------------------------------
# Modify the holiday class to 
# 1. Only accept Datetime objects for date.
# 2. You may need to add additional functions
# 3. You may drop the init if you are using @dataclasses
# --------------------------------------------
@dataclass
class Holiday:
    name: str
    date: datetime.date

    # def __init__(self,name, date):
    #     #Your Code Here
    #     pass        
    
    def __str__ (self):
        return f"{self.name} ({self.date})"
        # String output
        # Holiday output when printed.
        pass
          
           
# -------------------------------------------
# The HolidayList class acts as a wrapper and container
# For the list of holidays
# Each method has pseudo-code instructions
# --------------------------------------------
class HolidayList:
    def __init__(self):
        self.innerHolidays = []

    def addHoliday(self, holidayObj):
        # Make sure holidayObj is an Holiday Object by checking the type
        # Use innerHolidays.append(holidayObj) to add holiday
        # print to the user that you added a holiday
        self.innerHolidays.append(holidayObj)
#         print(hday_list.innerHolidays)

    def findHoliday(self, HolidayName, Date):
        # Find Holiday in innerHolidays
        # Return Holiday
        pass
    
    def removeHoliday(self, HolidayName, Date):
        # Find Holiday in innerHolidays by searching the name and date combination.
        # remove the Holiday from innerHolidays
        rem = {}
        rem["name"] = HolidayName
        rem["date"] = Date
        rem = Holiday(rem["name"], rem["date"])
        
        for i in range(len(self.innerHolidays)):
            if self.innerHolidays[i]==rem:
                print("You deleted " + HolidayName + " successfully!")
                self.innerHolidays.pop(i)
        if rem not in self.innerHolidays:
            print("Invalid holiday.\nIts possible we don't have that holiday or you input the information incorrectly.\nPlease double check the name and date and try again.")

        
        # inform user you deleted the holiday

    
    def read_json(self, filelocation):
        global holidayjson
        global hday
#         global holiday
        # Read in things from json file location
        with open(filelocation, 'r') as f:
#             self.innerHolidays = json.load(f)
#         return self.innerHolidays
            holidayjson = json.load(f)
            for holiday in holidayjson["holidays"]:
                hday = Holiday(holiday["name"], holiday["date"])
                self.addHoliday(hday)
        # Use addHoliday function to add holidays to inner list.
        


    def save_to_json(self, filelocation):
        fn = 'allholidays.json'
        dict_translate = {"holidays":[{"name": h.name, "date": h.date} for h in self.innerHolidays]}
        with open(fn, 'w') as f:
            json.dump(dict_translate, f, indent=4, default=str)
        # Write out json file to selected file.

        
    def scrapeHolidays(self):
        # Scrape Holidays from https://www.timeanddate.com/holidays/us/ 
        days = []
        dates = []
        years = ['2020', '2021', '2022', '2023', '2024']
        for year in years:
            url_list = [f'https://www.timeanddate.com/holidays/us/{year}']
            for i in range(len(url_list)):
                r = requests.get(url_list[i])
                soup = BeautifulSoup(r.text, 'html.parser')
                table = soup.find('table', attrs = {'id':'holidays-table'})
                body = table.find('tbody')
                rows = body.find_all('tr')
                for row in rows:
                    daywrappers = row.find_all('td')
                    datewrappers = row.find_all('th')
                    if datewrappers != []:
                        date = datewrappers[0].get_text()
                        date_string = f"{date}, {year}"
                        fdatetime = datetime.datetime.strptime(date_string, "%b %d, %Y")
                        fdate = fdatetime.date()
                        dates.append(fdate)
        #                 print(fdate)
                    if daywrappers != []:
                        dayname = daywrappers[1].get_text()
        #                 print(dayname)
                        days.append(dayname)

        scraped = zip(days, dates)
        scrapedlist = (list(scraped))
        for i in scrapedlist:
            hday_list.addHoliday(Holiday(i[0], i[1]))





        # hday_list.addHoliday(day)
                # Remember, 2 previous years, current year, and 2  years into the future. You can scrape multiple years by adding year to the timeanddate URL. For example https://www.timeanddate.com/holidays/us/2022
                # Check to see if name and date of holiday is in innerHolidays array
                # Add non-duplicates to innerHolidays
                # Handle any exceptions.


    def numHolidays(self):
        global lenHolidays
        # Return the total number of holidays in innerHolidays
        lenHolidays = len(self.innerHolidays) 
        return lenHolidays
    
    def filter_holidays_by_week(self, year, week_number):
        global holidayList
        global weekdateList
        weekdateList = []
        holidayList = []
        for i in self.innerHolidays:
            idate = i.date
            try:
                weekdate = idate.isocalendar()
            except:
                exceptYear = (i.date[0:4])
                exceptMonth = (i.date[5:7])
                exceptDay = (i.date[8:10])
                exceptDate = datetime.date(int(exceptYear),int(exceptMonth),int(exceptDay))
                weekdate = exceptDate.isocalendar()
            weekdateList.append(weekdate)
            yr, wk, wkday = weekdate
            if yr == int(year) and wk == int(week_number) and wkday in range(1,8):
                holidayList.append(i)
        # Use a Lambda function to filter by week number and save this as holidays, use the filter on innerHolidays
        # Week number is part of the the Datetime object
        # Cast filter results as list
        # return your holidays
        self.displayHolidaysInWeek(holidayList)

        
# for i in range(len(hday_list.innerHolidays)):
#     print(hday_list.innerHolidays[i])
    

    def displayHolidaysInWeek(self, holidayList):
        # Use your filter_holidays_by_week to get list of holidays within a week as a parameter
        # Output formated holidays in the week. 
        # * Remember to use the holiday __str__ method.
        for holiday in holidayList:
            print(str(holiday))


    def viewCurrentWeek(self):
        # Use the Datetime Module to look up current week and year
        today = datetime.date.today().isocalendar()
        tyr, twk, twkday = today
        self.filter_holidays_by_week(tyr, twk)

        # Use your filter_holidays_by_week function to get the list of holidays 
        # for the current week/year
        # Use your displayHolidaysInWeek function to display the holidays in the week
        # Ask user if they want to get the weather
        # If yes, use your getWeather function and display results
        pass

# %%
import datetime

def main():
    global done
    global lenlist
    global hday_list
    # Large Pseudo Code steps
    # -------------------------------------
    # 1. Initialize HolidayList Object
    hday_list = HolidayList()
    
    
#     lenlist = hday_list.numHolidays()
#     lenlist = str(len(hday_list.innerHolidays))
    
    # 2. Load JSON file via HolidayList read_json function
    hday_list.read_json('holidays.json') 
    # 3. Scrape additional holidays using your HolidayList scrapeHolidays function.
    hday_list.scrapeHolidays() 
    # 3. Create while loop for user to keep adding or working with the Calender
    # 4. Display User Menu (Print the menu)
    done = False
    while done == False:
        done = Title()

    
    
    # 5. Take user input for their action based on Menu and check the user input for errors
    # 6. Run appropriate method from the HolidayList object depending on what the user input is
    # 7. Ask the User if they would like to Continue, if not, end the while loop, ending the program.  If they do wish to continue, keep the program going. 
    pass

def Title():
    global done
    global lenlist
    greeting = print(f"\nWelcome to the Holidays App!\n==============\nThere are {(len(hday_list.innerHolidays))} holidays currently stored.")
    greeting
    uinput = input("\nHoliday Menu\n===============\n1. Add a Holiday\n2. Remove a Holiday\n3. Save Holiday List\n4. View Holidays\n5. Exit\nPlease input an option from 1-5.\n")
    if uinput == "1":
        addHday()
    elif uinput == "2":
        remHday()
    elif uinput == "3":
        saveList()
    elif uinput == "4":
        viewHolidays()
    elif uinput == "5":
        leave = input("Are you sure you want to exit? All unsaved changes will be lost!\n1. Yes\n2. No\n")
        if leave == "1":
            print("Goodbye!")
            done = True
            return True
        elif leave == "2":
            Title()
        else:
            print("Not a valid input.")
            Title()
    else:
        print("Not a valid input.")
        Title()


def addHday():
    print("\n1. Add a Holiday\n===============")
    validDate = False
    addHolidayName = input("Please input the Holiday's name.\n")
    while validDate == False:
        addHolidayDateYear = input(f"Please input the year of the Holiday in yyyy format.\n(Eg. For Dec 3, 2022 this input would be '2022')\n")
        addHolidayDateMonth = input(f"Please input the month of the Holiday in number format.\n(Eg. For Dec 3, 2022 this input would be '12' and for January 12, 2022, this input would be '1')\n")
        addHolidayDateDay = input(f"Please input the day of the Holiday in number format.\n(Eg. For Dec 3, 2022 this input would be '3' and for January 12, 2022, this input would be '12')\n")
        try:
            addHolidayDate = datetime.date(int(addHolidayDateYear), int(addHolidayDateMonth), int(addHolidayDateDay))           
            validDate = True
            break
        except:
            print("That didn't work. Please check the format instructions and try again.")
            continue
    addHolidayObj = Holiday(addHolidayName, addHolidayDate)
    hday_list.addHoliday(addHolidayObj)
    print(f"Successfully added {addHolidayName}.")
    contaddHday = input("Would you like to add another holiday?\n1. Yes\n2. No\n")
    if contaddHday == "1":
        addHday()
    elif contaddHday == "2":
        Title()
        
        
        
def remHday():
    print("\n2. Remove a Holiday\n===============")
    validDate = False
    remHolidayName = input("Please input the Holiday's name.\n")
    while validDate == False:
        remHolidayDateYear = input(f"Please input the year of the Holiday in yyyy format.\n(Eg. For Dec 3, 2022 this input would be '2022')\n")
        remHolidayDateMonth = input(f"Please input the month of the Holiday in number format.\n(Eg. For Dec 3, 2022 this input would be '12' and for January 12, 2022, this input would be '1')\n")
        remHolidayDateDay = input(f"Please input the day of the Holiday in number format.\n(Eg. For Dec 3, 2022 this input would be '3' and for January 12, 2022, this input would be '12')\n")
        try:
            remHolidayDate = datetime.date(int(remHolidayDateYear), int(remHolidayDateMonth), int(remHolidayDateDay))           
            break
        except:
            print("That didn't work. Please check the format instructions and try again.")
            pass
    hday_list.removeHoliday(remHolidayName, remHolidayDate)
    contremHday = input("Would you like to remove another holiday?\n1. Yes\n2. No\n")
    if contremHday == "1":
        remHday()
    elif contremHday == "2":
        Title()
        
        
        
def saveList():
    print("\n3. Save Holiday List\n===============")
    print("Saving...")
    hday_list.save_to_json('allholidays.json')
    print("Saved successfully!\nLocation: allholidays.json")
    Title()
    

    

    
    
def viewHolidays():
    valid = False
    viewYear = int(input("What year?\n"))
    while viewYear not in range(2020,2025):
        viewYear = int(input("Not in range, please input year from 2020 to 2024.\n"))
    while valid == False:
        viewWeek = input("What week? (1-52, leave blank for the current week)\n")
        if viewWeek == "":
            print("Showing the current week's holidays.\n")
            valid = True
            hday_list.viewCurrentWeek()
        elif int(viewWeek) in (range(1,53)):  
            print(f"Showing week {viewWeek}'s holidays.\n")
            valid = True
            hday_list.filter_holidays_by_week(viewYear, viewWeek)
        else:
            print("Not a valid input. Input a week from 1-52 or leave blank for the current week.")
    contviewHday = input("Would you like to view another week?\n1. Yes\n2. No\n")
    if contviewHday == "1":
        viewHolidays()
    elif contviewHday == "2":
        Title()

# %%
# DONT DELETE ####################################################################################################
if __name__ == "__main__":
    main();


# # Additional Hints:
# # ---------------------------------------------
# # You may need additional helper functions both in and out of the classes, add functions as you need to.
# #
# # No one function should be more then 50 lines of code, if you need more then 50 lines of code
# # excluding comments, break the function into multiple functions.
# #
# # You can store your raw menu text, and other blocks of texts as raw text files 
# # and use placeholder values with the format option.
# # Example:
# # In the file test.txt is "My name is {fname}, I'm {age}"
# # Then you later can read the file into a string "filetxt"
# # and substitute the placeholders 
# # for example: filetxt.format(fname = "John", age = 36)
# # This will make your code far more readable, by seperating text from code.
# Out:
# Welcome to the Holidays App!
# ==============
# There are 2823 holidays currently stored.
#
# Holiday Menu
# ===============
# 1. Add a Holiday
# 2. Remove a Holiday
# 3. Save Holiday List
# 4. View Holidays
# 5. Exit
# Please input an option from 1-5.
# 2
#
# 2. Remove a Holiday
# ===============
# Please input the Holiday's name.
# pee
# Please input the year of the Holiday in yyyy format.
# (Eg. For Dec 3, 2022 this input would be '2022')
# 12
# Please input the month of the Holiday in number format.
# (Eg. For Dec 3, 2022 this input would be '12' and for January 12, 2022, this input would be '1')
# 2
# Please input the day of the Holiday in number format.
# (Eg. For Dec 3, 2022 this input would be '3' and for January 12, 2022, this input would be '12')
# 2
# Invalid holiday.
# Its possible we don't have that holiday or you input the information incorrectly.
# Please double check the name and date and try again.
# Would you like to remove another holiday?
# 1. Yes
# 2. No
# 2
#
# Welcome to the Holidays App!
# ==============
# There are 2823 holidays currently stored.
#
# Holiday Menu
# ===============
# 1. Add a Holiday
# 2. Remove a Holiday
# 3. Save Holiday List
# 4. View Holidays
# 5. Exit
# Please input an option from 1-5.
# 4
# What year?
# 2020
# What week? (1-52, leave blank for the current week)
# 52
# Showing week 52's holidays.
#
# December Solstice (2020-12-21)
# Christmas Eve (2020-12-24)
# Christmas Eve (2020-12-24)
# Christmas Eve (2020-12-24)
# Washington's Birthday (2020-12-24)
# Asarah B'Tevet (2020-12-25)
# Christmas Day (2020-12-25)
# Christmas Day (2020-12-25)
# Kwanzaa (first day) (2020-12-26)
# Day After Christmas Day (2020-12-26)
# International Day of Epidemic Preparedness (2020-12-27)
# Would you like to view another week?
# 1. Yes
# 2. No
# 1
# What year?
# 2020
# What week? (1-52, leave blank for the current week)
# 53
# Not a valid input. Input a week from 1-52 or leave blank for the current week.
# What week? (1-52, leave blank for the current week)
#
# Showing the current week's holidays.
#
# International Day of Neutrality (2022-12-12)
# International Universal Health Coverage Day (2022-12-12)
# Feast of Our Lady of Guadalupe (2022-12-12)
# National Guard Birthday (2022-12-13)
# Bill of Rights Day (2022-12-15)
# Pan American Aviation Day (2022-12-17)
# Wright Brothers Day (2022-12-17)
# International Migrants Day (2022-12-18)
# Arabic Language Day (2022-12-18)
# Would you like to view another week?
# 1. Yes
# 2. No
# 1
# What year?
# 2021
# What week? (1-52, leave blank for the current week)
# 1
# Showing week 1's holidays.
#
# Margaret Thatcher Day (2021-01-10)
# World Braille Day (2021-01-04)
# Epiphany (2021-01-06)
# Orthodox Christmas Day (2021-01-07)
# International Programmers' Day (2021-01-07)
# Estelle Reel Day (2021-01-07)
# Battle of New Orleans (2021-01-08)
# Would you like to view another week?
# 1. Yes
# 2. No
# 1
# What year?
# 2020
# What week? (1-52, leave blank for the current week)
# 0
# Not a valid input. Input a week from 1-52 or leave blank for the current week.
# What week? (1-52, leave blank for the current week)
#
# Showing the current week's holidays.
#
# International Day of Neutrality (2022-12-12)
# International Universal Health Coverage Day (2022-12-12)
# Feast of Our Lady of Guadalupe (2022-12-12)
# National Guard Birthday (2022-12-13)
# Bill of Rights Day (2022-12-15)
# Pan American Aviation Day (2022-12-17)
# Wright Brothers Day (2022-12-17)
# International Migrants Day (2022-12-18)
# Arabic Language Day (2022-12-18)
# Would you like to view another week?
# 1. Yes
# 2. No
# 2
#
# Welcome to the Holidays App!
# ==============
# There are 2823 holidays currently stored.
#
# Holiday Menu
# ===============
# 1. Add a Holiday
# 2. Remove a Holiday
# 3. Save Holiday List
# 4. View Holidays
# 5. Exit
# Please input an option from 1-5.
# 5
# Are you sure you want to exit? All unsaved changes will be lost!
# 1. Yes
# 2. No
# 1
# Goodbye!

# %%
hday_list.innerHolidays
# Out:
# [Holiday(name='Margaret Thatcher Day', date='2021-01-10'),
#  Holiday(name='World Sketchnote Day', date='2021-01-11'),
#  Holiday(name='Zanzibar Revolution Day', date='2021-01-12'),
#  Holiday(name='National Rubber Ducky Day', date='2021-01-13'),
#  Holiday(name='Tamil Thai Pongdal Day', date='2021-01-14'),
#  Holiday(name='National Bagel Day', date='2021-01-15'),
#  Holiday(name='Signing of the Peace Accords', date='2021-01-16'),
#  Holiday(name="New Year's Day", date=datetime.date(2020, 1, 1)),
#  Holiday(name='World Braille Day', date=datetime.date(2020, 1, 4)),
#  Holiday(name='Epiphany', date=datetime.date(2020, 1, 6)),
#  Holiday(name="Asarah B'Tevet", date=datetime.date(2020, 1, 7)),
#  Holiday(name='Orthodox Christmas Day', date=datetime.date(2020, 1, 7)),
#  Holiday(name="International Programmers' Day", date=datetime.date(2020, 1, 7)),
#  Holiday(name='Estelle Reel Day', date=datetime.date(2020, 1, 7)),
#  Holiday(name='Battle of New Orleans', date=datetime.date(2020, 1, 8)),
#  Holiday(name='Stephen Foster Memorial Day', date=datetime.date(2020, 1, 13)),
#  Holiday(name='Orthodox New Year', date=datetime.date(2020, 1, 14)),
#  Holiday(name='Lee-Jackson Day', date=datetime.date(2020, 1, 17)),
#  Holiday(name='World Religion Day', date=datetime.date(2020, 1, 19)),
#  Holiday(name="Robert E. Lee's Birthday", date=datetime.date(2020, 1, 19)),
#  Holiday(name='State Holiday', date=datetime.date(2020, 1, 19)),
#  Holiday(name="Confederate Heroes' Day", date=datetime.date(2020, 1, 19)),
#  Holiday(name='Martin Luther King Jr. Day', date=datetime.date(2020, 1, 20)),
#  Holiday(name="Robert E. Lee's Birthday", date=datetime.date(2020, 1, 20)),
#  Holiday(name='Idaho Human Rights Day', date=datetime.date(2020, 1, 20)),
#  Holiday(name='Civil Rights Day', date=datetime.date(2020, 1, 20)),
#  Holiday(name='International Day of Education', date=datetime.date(2020, 1, 24)),
#  Holiday(name='Lunar New Year', date=datetime.date(2020, 1, 25)),
#  Holiday(name='International Customs Day', date=datetime.date(2020, 1, 26)),
#  Holiday(name='World Leprosy Day', date=datetime.date(2020, 1, 26)),
#  Holiday(name='International Day of Commemoration in Memory of the Victims of the Holocaust', date=datetime.date(2020, 1, 27)),
#  Holiday(name='Kansas Day', date=datetime.date(2020, 1, 29)),
#  Holiday(name='National Freedom Day', date=datetime.date(2020, 2, 1)),
#  Holiday(name='First Day of Black History Month', date=datetime.date(2020, 2, 1)),
#  Holiday(name='World Wetlands Day', date=datetime.date(2020, 2, 2)),
#  Holiday(name='Groundhog Day', date=datetime.date(2020, 2, 2)),
#  Holiday(name='Super Bowl', date=datetime.date(2020, 2, 2)),
#  Holiday(name='World Cancer Day', date=datetime.date(2020, 2, 4)),
#  Holiday(name='Rosa Parks Day', date=datetime.date(2020, 2, 4)),
#  Holiday(name='Rosa Parks Day', date=datetime.date(2020, 2, 4)),
#  Holiday(name='National Girls and Women in Sports Day', date=datetime.date(2020, 2, 5)),
#  Holiday(name='International Day of Zero Tolerance for Female Genital Mutilation', date=datetime.date(2020, 2, 6)),
#  Holiday(name='Ronald Reagan Day', date=datetime.date(2020, 2, 6)),
#  Holiday(name='National Wear Red Day', date=datetime.date(2020, 2, 7)),
#  Holiday(name="Tu Bishvat/Tu B'Shevat", date=datetime.date(2020, 2, 10)),
#  Holiday(name='World Pulses Day', date=datetime.date(2020, 2, 10)),
#  Holiday(name='International Day of Women and Girls in Science', date=datetime.date(2020, 2, 11)),
#  Holiday(name='World Day of the Sick', date=datetime.date(2020, 2, 11)),
#  Holiday(name="Lincoln's Birthday", date=datetime.date(2020, 2, 12)),
#  Holiday(name="Lincoln's Birthday", date=datetime.date(2020, 2, 12)),
#  Holiday(name='Georgia Day', date=datetime.date(2020, 2, 12)),
#  Holiday(name='World Radio Day', date=datetime.date(2020, 2, 13)),
#  Holiday(name="Valentine's Day", date=datetime.date(2020, 2, 14)),
#  Holiday(name='Statehood Day', date=datetime.date(2020, 2, 14)),
#  Holiday(name="Susan B. Anthony's Birthday", date=datetime.date(2020, 2, 15)),
#  Holiday(name='Elizabeth Peratrovich Day', date=datetime.date(2020, 2, 16)),
#  Holiday(name="Presidents' Day", date=datetime.date(2020, 2, 17)),
#  Holiday(name="Presidents' Day", date=datetime.date(2020, 2, 17)),
#  Holiday(name="Presidents' Day", date=datetime.date(2020, 2, 17)),
#  Holiday(name='Daisy Gatson Bates Day', date=datetime.date(2020, 2, 17)),
#  Holiday(name='World Day of Social Justice', date=datetime.date(2020, 2, 20)),
#  Holiday(name='Maha Shivaratri', date=datetime.date(2020, 2, 21)),
#  Holiday(name='International Mother Language Day', date=datetime.date(2020, 2, 21)),
#  Holiday(name='African-American Scientist and Inventor Day', date=datetime.date(2020, 2, 25)),
#  Holiday(name='Shrove Tuesday/Mardi Gras', date=datetime.date(2020, 2, 25)),
#  Holiday(name='Shrove Tuesday/Mardi Gras', date=datetime.date(2020, 2, 25)),
#  Holiday(name='George Rogers Clark Day', date=datetime.date(2020, 2, 25)),
#  Holiday(name='Ash Wednesday', date=datetime.date(2020, 2, 26)),
#  Holiday(name='Linus Pauling Day', date=datetime.date(2020, 2, 28)),
#  Holiday(name='Leap Day', date=datetime.date(2020, 2, 29)),
#  Holiday(name='Zero Discrimination Day', date=datetime.date(2020, 3, 1)),
#  Holiday(name='Self-Injury Awareness Day', date=datetime.date(2020, 3, 1)),
#  Holiday(name="St. David's Day", date=datetime.date(2020, 3, 1)),
#  Holiday(name="First Day of Women's History Month", date=datetime.date(2020, 3, 1)),
#  Holiday(name='First Day of Irish American Heritage Month', date=datetime.date(2020, 3, 1)),
#  Holiday(name='Texas Independence Day', date=datetime.date(2020, 3, 2)),
#  Holiday(name='Casimir Pulaski Day', date=datetime.date(2020, 3, 2)),
#  Holiday(name='Read Across America Day', date=datetime.date(2020, 3, 2)),
#  Holiday(name='World Wildlife Day', date=datetime.date(2020, 3, 3)),
#  Holiday(name='Super Tuesday', date=datetime.date(2020, 3, 3)),
#  Holiday(name='Town Meeting Day', date=datetime.date(2020, 3, 3)),
#  Holiday(name='Casimir Pulaski Day', date=datetime.date(2020, 3, 4)),
#  Holiday(name='Employee Appreciation Day', date=datetime.date(2020, 3, 6)),
#  Holiday(name="International Women's Day", date=datetime.date(2020, 3, 8)),
#  Holiday(name='Daylight Saving Time starts', date=datetime.date(2020, 3, 8)),
#  Holiday(name='Holi', date=datetime.date(2020, 3, 9)),
#  Holiday(name='Purim', date=datetime.date(2020, 3, 10)),
#  Holiday(name='World Kidney Day', date=datetime.date(2020, 3, 12)),
#  Holiday(name='Friday the 13th', date=datetime.date(2020, 3, 13)),
#  Holiday(name="St. Patrick's Day", date=datetime.date(2020, 3, 17)),
#  Holiday(name='Evacuation Day', date=datetime.date(2020, 3, 17)),
#  Holiday(name='First Day of Stay at Home Order', date=datetime.date(2020, 3, 19)),
#  Holiday(name='March Equinox', date=datetime.date(2020, 3, 19)),
#  Holiday(name='French Language Day', date=datetime.date(2020, 3, 20)),
#  Holiday(name='International Day of Happiness', date=datetime.date(2020, 3, 20)),
#  Holiday(name='First Day of Stay at Home Directive', date=datetime.date(2020, 3, 20)),
#  Holiday(name='International Day for the Elimination of Racial Discrimination', date=datetime.date(2020, 3, 21)),
#  Holiday(name='World Poetry Day', date=datetime.date(2020, 3, 21)),
#  Holiday(name='International Day of Nowruz', date=datetime.date(2020, 3, 21)),
#  Holiday(name='World Down Syndrome Day', date=datetime.date(2020, 3, 21)),
#  Holiday(name='International Day of Forests', date=datetime.date(2020, 3, 21)),
#  Holiday(name='First Day of Stay at Home Order', date=datetime.date(2020, 3, 21)),
#  Holiday(name="Isra and Mi'raj", date=datetime.date(2020, 3, 22)),
#  Holiday(name='World Water Day', date=datetime.date(2020, 3, 22)),
#  Holiday(name='First Day of Stay at Home Order', date=datetime.date(2020, 3, 22)),
#  Holiday(name='World Meteorological Day', date=datetime.date(2020, 3, 23)),
#  Holiday(name='First Day of Stay Safe, Stay Home Order', date=datetime.date(2020, 3, 23)),
#  Holiday(name='World Tuberculosis Day', date=datetime.date(2020, 3, 24)),
#  Holiday(name='International Day for the Right to the Truth concerning Gross Human Rights Violations and for the Dignity of Victims', date=datetime.date(2020, 3, 24)),
#  Holiday(name='First Day of Stay at Home Order', date=datetime.date(2020, 3, 24)),
#  Holiday(name='International Day of Remembrance of Slavery Victims and the Transatlantic Slave Trade', date=datetime.date(2020, 3, 25)),
#  Holiday(name='International Day of Solidarity with Detained and Missing Staff Members', date=datetime.date(2020, 3, 25)),
#  Holiday(name='First Day of Stay at Home Order', date=datetime.date(2020, 3, 25)),
#  Holiday(name='Maryland Day', date=datetime.date(2020, 3, 25)),
#  Holiday(name='First Day of Stay at Home Order', date=datetime.date(2020, 3, 26)),
#  Holiday(name='Prince Jonah Kuhio Kalanianaole Day', date=datetime.date(2020, 3, 26)),
#  Holiday(name='First Day of Stay at Home Order', date=datetime.date(2020, 3, 27)),
#  Holiday(name='Earth Hour', date=datetime.date(2020, 3, 28)),
#  Holiday(name='First Day of Stay at Home Order', date=datetime.date(2020, 3, 28)),
#  Holiday(name='First Day of Stay at Home Order', date=datetime.date(2020, 3, 29)),
#  Holiday(name='National Vietnam War Veterans Day', date=datetime.date(2020, 3, 29)),
#  Holiday(name='First Day of Stay at Home Order', date=datetime.date(2020, 3, 30)),
#  Holiday(name='Wyoming Veterans Welcome Home Day', date=datetime.date(2020, 3, 30)),
#  Holiday(name="Doctors' Day", date=datetime.date(2020, 3, 30)),
#  Holiday(name="Seward's Day", date=datetime.date(2020, 3, 30)),
#  Holiday(name='Vietnam Veterans Day', date=datetime.date(2020, 3, 30)),
#  Holiday(name='First Day of Stay at Home Order', date=datetime.date(2020, 3, 31)),
#  Holiday(name='César Chávez Day', date=datetime.date(2020, 3, 31)),
#  Holiday(name="April Fool's Day", date=datetime.date(2020, 4, 1)),
#  Holiday(name='First Day of Stay at Home Order', date=datetime.date(2020, 4, 1)),
#  Holiday(name='World Autism Awareness Day', date=datetime.date(2020, 4, 2)),
#  Holiday(name='First Day of Stay at Home Order', date=datetime.date(2020, 4, 2)),
#  Holiday(name='Pascua Florida Day', date=datetime.date(2020, 4, 2)),
#  Holiday(name='First Day of Stay at Home Order', date=datetime.date(2020, 4, 3)),
#  Holiday(name="United Nations' Mine Awareness Day", date=datetime.date(2020, 4, 4)),
#  Holiday(name='First Day of Stay at Home Order', date=datetime.date(2020, 4, 4)),
#  Holiday(name='Palm Sunday', date=datetime.date(2020, 4, 5)),
#  Holiday(name='International Day of Conscience', date=datetime.date(2020, 4, 5)),
#  Holiday(name='International Day of Sport for Development and Peace', date=datetime.date(2020, 4, 6)),
#  Holiday(name='First Day of Stay at Home Order', date=datetime.date(2020, 4, 6)),
#  Holiday(name='National Tartan Day', date=datetime.date(2020, 4, 6)),
#  Holiday(name="United Nations' World Health Day", date=datetime.date(2020, 4, 7)),
#  Holiday(name='Day of Remembrance of the Victims of the Rwanda Genocide', date=datetime.date(2020, 4, 7)),
#  Holiday(name='First Day of Stay at Home Order', date=datetime.date(2020, 4, 7)),
#  Holiday(name='Passover Eve', date=datetime.date(2020, 4, 8)),
#  Holiday(name='Maundy Thursday', date=datetime.date(2020, 4, 9)),
#  Holiday(name='Passover (first day)', date=datetime.date(2020, 4, 9)),
#  Holiday(name='National Former Prisoner of War Recognition Day', date=datetime.date(2020, 4, 9)),
#  Holiday(name='Good Friday', date=datetime.date(2020, 4, 10)),
#  Holiday(name='State Holiday', date=datetime.date(2020, 4, 10)),
#  Holiday(name='Holy Saturday', date=datetime.date(2020, 4, 11)),
#  Holiday(name='International Day of Human Space Flight', date=datetime.date(2020, 4, 12)),
#  Holiday(name='Easter Sunday', date=datetime.date(2020, 4, 12)),
#  Holiday(name='Easter Monday', date=datetime.date(2020, 4, 13)),
#  Holiday(name="Thomas Jefferson's Birthday", date=datetime.date(2020, 4, 13)),
#  Holiday(name='World Chagas Disease Day', date=datetime.date(2020, 4, 14)),
#  Holiday(name='World Art Day', date=datetime.date(2020, 4, 15)),
#  Holiday(name='Father Damien Day', date=datetime.date(2020, 4, 15)),
#  Holiday(name='Last Day of Passover', date=datetime.date(2020, 4, 16)),
#  Holiday(name='Emancipation Day', date=datetime.date(2020, 4, 16)),
#  Holiday(name='Orthodox Good Friday', date=datetime.date(2020, 4, 17)),
#  Holiday(name='Arbor Day', date=datetime.date(2020, 4, 17)),
#  Holiday(name='Orthodox Holy Saturday', date=datetime.date(2020, 4, 18)),
#  Holiday(name='International Day for Monuments and Sites', date=datetime.date(2020, 4, 18)),
#  Holiday(name='Orthodox Easter', date=datetime.date(2020, 4, 19)),
#  Holiday(name='Orthodox Easter Monday', date=datetime.date(2020, 4, 20)),
#  Holiday(name='Chinese Language Day', date=datetime.date(2020, 4, 20)),
#  Holiday(name="Patriots' Day", date=datetime.date(2020, 4, 20)),
#  Holiday(name='Yom HaShoah', date=datetime.date(2020, 4, 21)),
#  Holiday(name='World Creativity and Innovation Day', date=datetime.date(2020, 4, 21)),
#  Holiday(name='Last Day of Stay at Home Order', date=datetime.date(2020, 4, 21)),
#  Holiday(name='San Jacinto Day', date=datetime.date(2020, 4, 21)),
#  Holiday(name="National Library Workers' Day", date=datetime.date(2020, 4, 21)),
#  Holiday(name='Earth Day', date=datetime.date(2020, 4, 22)),
#  Holiday(name='Oklahoma Day', date=datetime.date(2020, 4, 22)),
#  Holiday(name='Administrative Professionals Day', date=datetime.date(2020, 4, 22)),
#  Holiday(name='World Book and Copyright Day', date=datetime.date(2020, 4, 23)),
#  Holiday(name='International Girls in ICT Day', date=datetime.date(2020, 4, 23)),
#  Holiday(name='English Language Day', date=datetime.date(2020, 4, 23)),
#  Holiday(name='Take our Daughters and Sons to Work Day', date=datetime.date(2020, 4, 23)),
#  Holiday(name='Ramadan Starts', date=datetime.date(2020, 4, 24)),
#  Holiday(name='International Day of Multilateralism and Diplomacy for Peace', date=datetime.date(2020, 4, 24)),
#  Holiday(name='Last Day of Stay at Home Directive', date=datetime.date(2020, 4, 24)),
#  Holiday(name='Arbor Day', date=datetime.date(2020, 4, 24)),
#  Holiday(name='Arbor Day', date=datetime.date(2020, 4, 24)),
#  Holiday(name="International Delegate's Day", date=datetime.date(2020, 4, 25)),
#  Holiday(name='World Malaria Day', date=datetime.date(2020, 4, 25)),
#  Holiday(name='World Intellectual Property Day', date=datetime.date(2020, 4, 26)),
#  Holiday(name='International Chernobyl Disaster Remembrance Day', date=datetime.date(2020, 4, 26)),
#  Holiday(name='Last Day of Stay at Home Order', date=datetime.date(2020, 4, 26)),
#  Holiday(name="Confederate Heroes' Day", date=datetime.date(2020, 4, 26)),
#  Holiday(name='State Holiday', date=datetime.date(2020, 4, 26)),
#  Holiday(name='Arbor Day', date=datetime.date(2020, 4, 27)),
#  Holiday(name='Confederate Memorial Day', date=datetime.date(2020, 4, 27)),
#  Holiday(name='Confederate Memorial Day', date=datetime.date(2020, 4, 27)),
#  Holiday(name="Confederate Heroes' Day observed", date=datetime.date(2020, 4, 27)),
#  Holiday(name='World Day for Safety and Health at Work', date=datetime.date(2020, 4, 28)),
#  Holiday(name="Yom Ha'atzmaut", date=datetime.date(2020, 4, 29)),
#  Holiday(name='International Jazz Day', date=datetime.date(2020, 4, 30)),
#  Holiday(name='Last Day of Stay at Home Order', date=datetime.date(2020, 4, 30)),
#  Holiday(name='Last Day of Stay at Home Directive', date=datetime.date(2020, 5, 1)),
#  Holiday(name='Kentucky Oaks', date=datetime.date(2020, 5, 1)),
#  Holiday(name='Law Day', date=datetime.date(2020, 5, 1)),
#  Holiday(name='Loyalty Day', date=datetime.date(2020, 5, 1)),
#  Holiday(name='Lei Day', date=datetime.date(2020, 5, 1)),
#  Holiday(name='First Day of Military Appreciation Month', date=datetime.date(2020, 5, 1)),
#  Holiday(name='First Day of Asian Pacific American Heritage Month', date=datetime.date(2020, 5, 1)),
#  Holiday(name='First Day of Jewish American Heritage Month', date=datetime.date(2020, 5, 1)),
#  Holiday(name='World Tuna Day', date=datetime.date(2020, 5, 2)),
#  Holiday(name='National Explosive Ordnance Disposal (EOD) Day', date=datetime.date(2020, 5, 2)),
#  Holiday(name='World Press Freedom Day', date=datetime.date(2020, 5, 3)),
#  Holiday(name='International Family Equality Day', date=datetime.date(2020, 5, 3)),
#  Holiday(name='Last Day of Stay at Home Order', date=datetime.date(2020, 5, 3)),
#  Holiday(name='Last Day of Stay at Home Order', date=datetime.date(2020, 5, 4)),
#  Holiday(name='Kent State Shootings Remembrance', date=datetime.date(2020, 5, 4)),
#  Holiday(name='Rhode Island Independence Day', date=datetime.date(2020, 5, 4)),
#  Holiday(name='World Portuguese Language Day', date=datetime.date(2020, 5, 5)),
#  Holiday(name='Cinco de Mayo', date=datetime.date(2020, 5, 5)),
#  Holiday(name='National Teacher Appreciation Day', date=datetime.date(2020, 5, 5)),
#  Holiday(name='National Nurses Day', date=datetime.date(2020, 5, 6)),
#  Holiday(name='Day of Vesak', date=datetime.date(2020, 5, 7)),
#  Holiday(name='National Day of Prayer', date=datetime.date(2020, 5, 7)),
#  Holiday(name='West Virginia Day of Prayer', date=datetime.date(2020, 5, 7)),
#  Holiday(name='Time of Remembrance and Reconciliation for Those Who Lost Their Lives during the Second World War', date=datetime.date(2020, 5, 8)),
#  Holiday(name='World Ovarian Cancer Day', date=datetime.date(2020, 5, 8)),
#  Holiday(name='World Red Cross and Red Crescent Day', date=datetime.date(2020, 5, 8)),
#  Holiday(name='Last Day of Stay at Home Order', date=datetime.date(2020, 5, 8)),
#  Holiday(name='Truman Day', date=datetime.date(2020, 5, 8)),
#  Holiday(name='Victory in Europe Day', date=datetime.date(2020, 5, 8)),
#  Holiday(name='Native American Day', date=datetime.date(2020, 5, 8)),
#  Holiday(name='Military Spouse Appreciation Day', date=datetime.date(2020, 5, 8)),
#  Holiday(name='Military Spouse Appreciation Day', date=datetime.date(2020, 5, 8)),
#  Holiday(name='World Migratory Bird Day', date=datetime.date(2020, 5, 9)),
#  Holiday(name="Mother's Day", date=datetime.date(2020, 5, 10)),
#  Holiday(name="Mother's Day", date=datetime.date(2020, 5, 10)),
#  Holiday(name='Confederate Memorial Day', date=datetime.date(2020, 5, 10)),
#  Holiday(name='Confederate Memorial Day', date=datetime.date(2020, 5, 10)),
#  Holiday(name='Confederate Memorial Day observed', date=datetime.date(2020, 5, 11)),
#  Holiday(name='Lag BaOmer', date=datetime.date(2020, 5, 12)),
#  Holiday(name='International Nurses Day', date=datetime.date(2020, 5, 12)),
#  Holiday(name='Last Day of Stay at Home Order', date=datetime.date(2020, 5, 13)),
#  Holiday(name='International Day of Families', date=datetime.date(2020, 5, 15)),
#  Holiday(name='Last Day of Stay at Home Order', date=datetime.date(2020, 5, 15)),
#  Holiday(name='Peace Officers Memorial Day', date=datetime.date(2020, 5, 15)),
#  Holiday(name='National Defense Transportation Day', date=datetime.date(2020, 5, 15)),
#  Holiday(name='International Day of Living Together in Peace', date=datetime.date(2020, 5, 16)),
#  Holiday(name='International Day of Light', date=datetime.date(2020, 5, 16)),
#  Holiday(name='Public Lands Day', date=datetime.date(2020, 5, 16)),
#  Holiday(name='Armed Forces Day', date=datetime.date(2020, 5, 16)),
#  Holiday(name='Preakness Stakes', date=datetime.date(2020, 5, 16)),
#  Holiday(name='World Telecommunication and Information Society Day', date=datetime.date(2020, 5, 17)),
#  Holiday(name='Last Day of Stay at Home Order', date=datetime.date(2020, 5, 17)),
#  Holiday(name='Last Day of Stay at Home Advisory', date=datetime.date(2020, 5, 18)),
#  Holiday(name='Lailat al-Qadr', date=datetime.date(2020, 5, 19)),
#  Holiday(name='Last Day of Stay at Home Order', date=datetime.date(2020, 5, 19)),
#  Holiday(name='World Bee Day', date=datetime.date(2020, 5, 20)),
#  Holiday(name='World Autoimmune / Autoinflammatory Arthritis Day', date=datetime.date(2020, 5, 20)),
#  Holiday(name='Last Day of Stay Safe, Stay Home Order', date=datetime.date(2020, 5, 20)),
#  Holiday(name='Emergency Medical Services for Children Day', date=datetime.date(2020, 5, 20)),
#  Holiday(name='Ascension Day', date=datetime.date(2020, 5, 21)),
#  Holiday(name='World Day for Cultural Diversity for Dialogue and Development', date=datetime.date(2020, 5, 21)),
#  Holiday(name='International Tea Day', date=datetime.date(2020, 5, 21)),
#  Holiday(name='International Day for Biological Diversity', date=datetime.date(2020, 5, 22)),
#  Holiday(name='Last Day of Stay at Home Order', date=datetime.date(2020, 5, 22)),
#  Holiday(name='National Maritime Day', date=datetime.date(2020, 5, 22)),
#  Holiday(name='Harvey Milk Day', date=datetime.date(2020, 5, 22)),
#  Holiday(name='International Day to End Obstetric Fistula', date=datetime.date(2020, 5, 23)),
#  Holiday(name='Eid al-Fitr', date=datetime.date(2020, 5, 24)),
#  Holiday(name='African Liberation Day', date=datetime.date(2020, 5, 25)),
#  Holiday(name='Last Day of Stay at Home Order', date=datetime.date(2020, 5, 25)),
#  Holiday(name='Memorial Day', date=datetime.date(2020, 5, 25)),
#  Holiday(name='Decoration Day', date=datetime.date(2020, 5, 25)),
#  Holiday(name="Jefferson Davis' Birthday", date=datetime.date(2020, 5, 25)),
#  Holiday(name="National Missing Children's Day", date=datetime.date(2020, 5, 25)),
#  Holiday(name='Shavuot', date=datetime.date(2020, 5, 29)),
#  Holiday(name='International Day of United Nations Peacekeepers', date=datetime.date(2020, 5, 29)),
#  Holiday(name='Last Day of Stay at Home Order', date=datetime.date(2020, 5, 29)),
#  Holiday(name='Last Day of Stay at Home Order', date=datetime.date(2020, 5, 30)),
#  Holiday(name='Pentecost', date=datetime.date(2020, 5, 31)),
#  Holiday(name='World No Tobacco Day', date=datetime.date(2020, 5, 31)),
#  Holiday(name='Last Day of Stay at Home Order', date=datetime.date(2020, 5, 31)),
#  Holiday(name='Whit Monday', date=datetime.date(2020, 6, 1)),
#  Holiday(name='Global Day of Parents', date=datetime.date(2020, 6, 1)),
#  Holiday(name='Last Day of Stay at Home Order', date=datetime.date(2020, 6, 1)),
#  Holiday(name='First Day of Pride Month', date=datetime.date(2020, 6, 1)),
#  Holiday(name='First Day of Caribbean-American Heritage Month', date=datetime.date(2020, 6, 1)),
#  Holiday(name='Statehood Day', date=datetime.date(2020, 6, 1)),
#  Holiday(name="Jefferson Davis' Birthday", date=datetime.date(2020, 6, 1)),
#  Holiday(name='World Bicycle Day', date=datetime.date(2020, 6, 3)),
#  Holiday(name="Jefferson Davis' Birthday", date=datetime.date(2020, 6, 3)),
#  Holiday(name='International Day of Innocent Children Victims of Aggression', date=datetime.date(2020, 6, 4)),
#  Holiday(name='Last Day of Stay at Home Order', date=datetime.date(2020, 6, 4)),
#  Holiday(name='World Environment Day', date=datetime.date(2020, 6, 5)),
#  Holiday(name='International Day for the Fight against Illegal, Unreported and Unregulated Fishing', date=datetime.date(2020, 6, 5)),
#  Holiday(name='Day of the Russian Language', date=datetime.date(2020, 6, 6)),
#  Holiday(name='D-Day', date=datetime.date(2020, 6, 6)),
#  Holiday(name='Belmont Stakes', date=datetime.date(2020, 6, 6)),
#  Holiday(name='Trinity Sunday', date=datetime.date(2020, 6, 7)),
#  Holiday(name='World Food Safety Day', date=datetime.date(2020, 6, 7)),
#  Holiday(name='Native American Day', date=datetime.date(2020, 6, 7)),
#  Holiday(name='World Oceans Day', date=datetime.date(2020, 6, 8)),
#  Holiday(name='Primary Election Day', date=datetime.date(2020, 6, 9)),
#  Holiday(name='Last Day of Stay at Home Order', date=datetime.date(2020, 6, 10)),
#  Holiday(name='Corpus Christi', date=datetime.date(2020, 6, 11)),
#  Holiday(name='Kamehameha Day', date=datetime.date(2020, 6, 11)),
#  Holiday(name='World Day Against Child Labour', date=datetime.date(2020, 6, 12)),
#  Holiday(name='Loving Day', date=datetime.date(2020, 6, 12)),
#  Holiday(name='International Albinism Awareness Day', date=datetime.date(2020, 6, 13)),
#  Holiday(name='Last Day of Stay at Home Order', date=datetime.date(2020, 6, 13)),
#  Holiday(name='World Blood Donor Day', date=datetime.date(2020, 6, 14)),
#  Holiday(name='Army Birthday', date=datetime.date(2020, 6, 14)),
#  Holiday(name='Flag Day', date=datetime.date(2020, 6, 14)),
#  Holiday(name='World Elder Abuse Awareness Day', date=datetime.date(2020, 6, 15)),
#  Holiday(name='Last Day of Stay at Home Order', date=datetime.date(2020, 6, 15)),
#  Holiday(name='International Day of Family Remittances', date=datetime.date(2020, 6, 16)),
#  Holiday(name='World Day to Combat Desertification and Drought', date=datetime.date(2020, 6, 17)),
#  Holiday(name='Bunker Hill Day', date=datetime.date(2020, 6, 17)),
#  Holiday(name='Sustainable Gastronomy Day', date=datetime.date(2020, 6, 18)),
#  Holiday(name='International Day for the Elimination of Sexual Violence in Conflict', date=datetime.date(2020, 6, 19)),
#  Holiday(name='Juneteenth', date=datetime.date(2020, 6, 19)),
#  Holiday(name='Juneteenth', date=datetime.date(2020, 6, 19)),
#  Holiday(name='Juneteenth National Freedom Day', date=datetime.date(2020, 6, 19)),
#  Holiday(name='Juneteenth Independence Day', date=datetime.date(2020, 6, 19)),
#  Holiday(name='Emancipation Day', date=datetime.date(2020, 6, 19)),
#  Holiday(name='World Refugee Day', date=datetime.date(2020, 6, 20)),
#  Holiday(name='Juneteenth Day', date=datetime.date(2020, 6, 20)),
#  Holiday(name='West Virginia Day', date=datetime.date(2020, 6, 20)),
#  Holiday(name='American Eagle Day', date=datetime.date(2020, 6, 20)),
#  Holiday(name='June Solstice', date=datetime.date(2020, 6, 20)),
#  Holiday(name='International Day of Yoga', date=datetime.date(2020, 6, 21)),
#  Holiday(name='International Day of the Celebration of the Solstice', date=datetime.date(2020, 6, 21)),
#  Holiday(name="Father's Day", date=datetime.date(2020, 6, 21)),
#  Holiday(name="Father's Day", date=datetime.date(2020, 6, 21)),
#  Holiday(name='Juneteenth Independence Day', date=datetime.date(2020, 6, 21)),
#  Holiday(name='Public Service Day', date=datetime.date(2020, 6, 23)),
#  Holiday(name="International Widows' Day", date=datetime.date(2020, 6, 23)),
#  Holiday(name='Day of the Seafarer', date=datetime.date(2020, 6, 25)),
#  Holiday(name='International Day Against Drug Abuse and Illicit Trafficking', date=datetime.date(2020, 6, 26)),
#  Holiday(name='International Day in Support of Victims of Torture', date=datetime.date(2020, 6, 26)),
#  Holiday(name='Micro-, Small and Medium-sized Enterprises Day', date=datetime.date(2020, 6, 27)),
#  Holiday(name='Carolina Day', date=datetime.date(2020, 6, 28)),
#  Holiday(name='International Day of the Tropics', date=datetime.date(2020, 6, 29)),
#  Holiday(name='International Asteroid Day', date=datetime.date(2020, 6, 30)),
#  Holiday(name='International Day of Parliamentarism', date=datetime.date(2020, 6, 30)),
#  Holiday(name='Independence Day (substitute)', date=datetime.date(2020, 7, 3)),
#  Holiday(name='Independence Day (substitute)', date=datetime.date(2020, 7, 3)),
#  Holiday(name='International Day of Cooperatives', date=datetime.date(2020, 7, 4)),
#  Holiday(name='Independence Day', date=datetime.date(2020, 7, 4)),
#  Holiday(name='Independence Day', date=datetime.date(2020, 7, 4)),
#  Holiday(name='Independence Day', date=datetime.date(2020, 7, 4)),
#  Holiday(name='World Population Day', date=datetime.date(2020, 7, 11)),
#  Holiday(name='Nathan Bedford Forrest Day', date=datetime.date(2020, 7, 13)),
#  Holiday(name='Bastille Day', date=datetime.date(2020, 7, 14)),
#  Holiday(name='World Youth Skills Day', date=datetime.date(2020, 7, 15)),
#  Holiday(name='Tax Day', date=datetime.date(2020, 7, 15)),
#  Holiday(name='Rural Transit Day', date=datetime.date(2020, 7, 16)),
#  Holiday(name='Nelson Mandela Day', date=datetime.date(2020, 7, 18)),
#  Holiday(name='World Chess Day', date=datetime.date(2020, 7, 20)),
#  Holiday(name='Pioneer Day', date=datetime.date(2020, 7, 24)),
#  Holiday(name="Parents' Day", date=datetime.date(2020, 7, 26)),
#  Holiday(name='Korean War Veteran Recognition Day', date=datetime.date(2020, 7, 27)),
#  Holiday(name='National Korean War Veterans Armistice Day', date=datetime.date(2020, 7, 27)),
#  Holiday(name='World Hepatitis Day', date=datetime.date(2020, 7, 28)),
#  Holiday(name="Tisha B'Av", date=datetime.date(2020, 7, 30)),
#  Holiday(name='International Day of Friendship', date=datetime.date(2020, 7, 30)),
#  Holiday(name='World Day Against Trafficking in Persons', date=datetime.date(2020, 7, 30)),
#  Holiday(name='Eid al-Adha', date=datetime.date(2020, 7, 31)),
#  Holiday(name='Colorado Day', date=datetime.date(2020, 8, 1)),
#  Holiday(name='American Family Day', date=datetime.date(2020, 8, 2)),
#  Holiday(name='Raksha Bandhan', date=datetime.date(2020, 8, 3)),
#  Holiday(name='Coast Guard Birthday', date=datetime.date(2020, 8, 4)),
#  Holiday(name='Barack Obama Day', date=datetime.date(2020, 8, 4)),
#  Holiday(name='Purple Heart Day', date=datetime.date(2020, 8, 7)),
#  Holiday(name='Purple Heart Day', date=datetime.date(2020, 8, 7)),
#  Holiday(name="International Day of the World's Indigenous People", date=datetime.date(2020, 8, 9)),
#  Holiday(name='Janmashtami', date=datetime.date(2020, 8, 10)),
#  Holiday(name='Victory Day', date=datetime.date(2020, 8, 10)),
#  Holiday(name='International Youth Day', date=datetime.date(2020, 8, 12)),
#  Holiday(name='Assumption of Mary', date=datetime.date(2020, 8, 15)),
#  Holiday(name='National Navajo Code Talkers Day', date=datetime.date(2020, 8, 16)),
#  Holiday(name='Bennington Battle Day', date=datetime.date(2020, 8, 16)),
#  Holiday(name='National Senior Citizens Day', date=datetime.date(2020, 8, 16)),
#  Holiday(name='Bennington Battle Day observed', date=datetime.date(2020, 8, 17)),
#  Holiday(name='World Humanitarian Day', date=datetime.date(2020, 8, 19)),
#  Holiday(name='National Aviation Day', date=datetime.date(2020, 8, 19)),
#  Holiday(name='Muharram', date=datetime.date(2020, 8, 20)),
#  Holiday(name='Ganesh Chaturthi', date=datetime.date(2020, 8, 21)),
#  Holiday(name='International Day of Remembrance of and Tribute to the Victims of Terrorism', date=datetime.date(2020, 8, 21)),
#  Holiday(name='Hawaii Statehood Day', date=datetime.date(2020, 8, 21)),
#  Holiday(name='International Day Commemorating the Victims of Acts of Violence Based on Religion or Belief', date=datetime.date(2020, 8, 22)),
#  Holiday(name='International Day for the Remembrance of the Slave Trade and its Abolition', date=datetime.date(2020, 8, 23)),
#  Holiday(name='Susan B. Anthony Day', date=datetime.date(2020, 8, 26)),
#  Holiday(name="Women's Equality Day", date=datetime.date(2020, 8, 26)),
#  Holiday(name='Lyndon Baines Johnson Day', date=datetime.date(2020, 8, 27)),
#  Holiday(name='Last Day of Stay at Home Instructions', date=datetime.date(2020, 8, 28)),
#  Holiday(name='Ashura', date=datetime.date(2020, 8, 29)),
#  Holiday(name='International Day against Nuclear Tests', date=datetime.date(2020, 8, 29)),
#  Holiday(name='International Day of the Victims of Enforced Disappearances', date=datetime.date(2020, 8, 30)),
#  Holiday(name='International Overdose Awareness Day', date=datetime.date(2020, 8, 31)),
#  Holiday(name='World Sexual Health Day', date=datetime.date(2020, 9, 4)),
#  Holiday(name='International Day of Charity', date=datetime.date(2020, 9, 5)),
#  Holiday(name='Kentucky Derby', date=datetime.date(2020, 9, 5)),
#  Holiday(name='International Day of Clean Air for Blue Skies', date=datetime.date(2020, 9, 7)),
#  Holiday(name="Still's Disease Awareness Day", date=datetime.date(2020, 9, 7)),
#  Holiday(name='Labor Day', date=datetime.date(2020, 9, 7)),
#  Holiday(name='International Literacy Day', date=datetime.date(2020, 9, 8)),
#  Holiday(name='International Day to Protect Education from Attack', date=datetime.date(2020, 9, 9)),
#  Holiday(name='California Admission Day', date=datetime.date(2020, 9, 9)),
#  Holiday(name='World Suicide Prevention Day', date=datetime.date(2020, 9, 10)),
#  Holiday(name='First Responders Day', date=datetime.date(2020, 9, 11)),
#  Holiday(name='Patriot Day', date=datetime.date(2020, 9, 11)),
#  Holiday(name='Patriot Day', date=datetime.date(2020, 9, 11)),
#  Holiday(name='International Day for South-South Cooperation', date=datetime.date(2020, 9, 12)),
#  Holiday(name="International Programmers' Day", date=datetime.date(2020, 9, 12)),
#  Holiday(name='Carl Garner Federal Lands Cleanup Day', date=datetime.date(2020, 9, 12)),
#  Holiday(name='Native American Day', date=datetime.date(2020, 9, 12)),
#  Holiday(name='National Grandparents Day', date=datetime.date(2020, 9, 13)),
#  Holiday(name='Constitution Commemoration Day', date=datetime.date(2020, 9, 13)),
#  Holiday(name='International Day of Democracy', date=datetime.date(2020, 9, 15)),
#  Holiday(name='First Day of National Hispanic Heritage Month', date=datetime.date(2020, 9, 15)),
#  Holiday(name='International Day for the Preservation of the Ozone Layer', date=datetime.date(2020, 9, 16)),
#  Holiday(name='World Patient Safety Day', date=datetime.date(2020, 9, 17)),
#  Holiday(name='Constitution Day and Citizenship Day', date=datetime.date(2020, 9, 17)),
#  Holiday(name='International Equal Pay Day', date=datetime.date(2020, 9, 18)),
#  Holiday(name='Air Force Birthday', date=datetime.date(2020, 9, 18)),
#  Holiday(name='National POW/MIA Recognition Day', date=datetime.date(2020, 9, 18)),
#  Holiday(name='Rosh Hashana', date=datetime.date(2020, 9, 19)),
#  Holiday(name='National CleanUp Day', date=datetime.date(2020, 9, 19)),
#  Holiday(name='Rosh Hashana', date=datetime.date(2020, 9, 19)),
#  Holiday(name='International Day of Peace', date=datetime.date(2020, 9, 21)),
#  Holiday(name='Emancipation Day', date=datetime.date(2020, 9, 22)),
#  Holiday(name='September Equinox', date=datetime.date(2020, 9, 22)),
#  Holiday(name='International Day of Sign Languages', date=datetime.date(2020, 9, 23)),
#  Holiday(name='International Celebrate Bisexuality Day', date=datetime.date(2020, 9, 23)),
#  Holiday(name='World Maritime Day', date=datetime.date(2020, 9, 24)),
#  Holiday(name='Native American Day', date=datetime.date(2020, 9, 25)),
#  Holiday(name='American Indian Heritage Day', date=datetime.date(2020, 9, 25)),
#  Holiday(name='Michigan Indian Day', date=datetime.date(2020, 9, 25)),
#  Holiday(name='International Day for the Total Elimination of Nuclear Weapons', date=datetime.date(2020, 9, 26)),
#  Holiday(name='Public Lands Day', date=datetime.date(2020, 9, 26)),
#  Holiday(name='National Public Lands Day', date=datetime.date(2020, 9, 26)),
#  Holiday(name='World Tourism Day', date=datetime.date(2020, 9, 27)),
#  Holiday(name="Gold Star Mother's Day", date=datetime.date(2020, 9, 27)),
#  Holiday(name='Yom Kippur', date=datetime.date(2020, 9, 28)),
#  Holiday(name='International Day for Universal Access to Information', date=datetime.date(2020, 9, 28)),
#  Holiday(name='World Rabies Day', date=datetime.date(2020, 9, 28)),
#  Holiday(name='American Indian Day', date=datetime.date(2020, 9, 28)),
#  Holiday(name='Yom Kippur', date=datetime.date(2020, 9, 28)),
#  Holiday(name='International Day of Awareness of Food Loss and Waste', date=datetime.date(2020, 9, 29)),
#  Holiday(name='World Heart Day', date=datetime.date(2020, 9, 29)),
#  Holiday(name='International Translation Day', date=datetime.date(2020, 9, 30)),
#  Holiday(name='International Day of Older Persons', date=datetime.date(2020, 10, 1)),
#  Holiday(name='World Vegetarian Day', date=datetime.date(2020, 10, 1)),
#  Holiday(name='International Day of Non-Violence', date=datetime.date(2020, 10, 2)),
#  Holiday(name='First Day of Sukkot', date=datetime.date(2020, 10, 3)),
#  Holiday(name='Feast of St Francis of Assisi', date=datetime.date(2020, 10, 4)),
#  Holiday(name="World Teachers' Day", date=datetime.date(2020, 10, 5)),
#  Holiday(name='World Habitat Day', date=datetime.date(2020, 10, 5)),
#  Holiday(name='Frances Xavier Cabrini Day', date=datetime.date(2020, 10, 5)),
#  Holiday(name='Child Health Day', date=datetime.date(2020, 10, 5)),
#  Holiday(name='World Cerebral Palsy Day', date=datetime.date(2020, 10, 6)),
#  Holiday(name='German American Day', date=datetime.date(2020, 10, 6)),
#  Holiday(name='World Sight Day', date=datetime.date(2020, 10, 8)),
#  Holiday(name='Last Day of Sukkot', date=datetime.date(2020, 10, 9)),
#  Holiday(name='World Post Day', date=datetime.date(2020, 10, 9)),
#  Holiday(name='Leif Erikson Day', date=datetime.date(2020, 10, 9)),
#  Holiday(name='Leif Erikson Day', date=datetime.date(2020, 10, 9)),
#  Holiday(name='Shmini Atzeret', date=datetime.date(2020, 10, 10)),
#  Holiday(name='World Mental Health Day', date=datetime.date(2020, 10, 10)),
#  Holiday(name="Robert E. Lee's Birthday", date=datetime.date(2020, 10, 10)),
#  Holiday(name='Chicago Marathon', date=datetime.date(2020, 10, 10)),
#  Holiday(name='Simchat Torah', date=datetime.date(2020, 10, 11)),
#  Holiday(name='International Day of the Girl Child', date=datetime.date(2020, 10, 11)),
#  Holiday(name='Casimir Pulaski Day', date=datetime.date(2020, 10, 11)),
#  Holiday(name='World Spanish Language Day', date=datetime.date(2020, 10, 12)),
#  Holiday(name='Columbus Day', date=datetime.date(2020, 10, 12)),
#  Holiday(name='Columbus Day', date=datetime.date(2020, 10, 12)),
#  Holiday(name='Columbus Day', date=datetime.date(2020, 10, 12)),
#  Holiday(name='Fraternal Day', date=datetime.date(2020, 10, 12)),
#  Holiday(name='Yorktown Victory Day', date=datetime.date(2020, 10, 12)),
#  Holiday(name='Discoverers’ Day', date=datetime.date(2020, 10, 12)),
#  Holiday(name='Native American Day', date=datetime.date(2020, 10, 12)),
#  Holiday(name='Native American Day', date=datetime.date(2020, 10, 12)),
#  Holiday(name="Indigenous People's Day", date=datetime.date(2020, 10, 12)),
#  Holiday(name="Indigenous People's Day", date=datetime.date(2020, 10, 12)),
#  Holiday(name='American Indian Heritage Day', date=datetime.date(2020, 10, 12)),
#  Holiday(name='Navy Birthday', date=datetime.date(2020, 10, 13)),
#  Holiday(name='International Day for Natural Disaster Reduction', date=datetime.date(2020, 10, 14)),
#  Holiday(name='International Day of Rural Women', date=datetime.date(2020, 10, 15)),
#  Holiday(name='White Cane Safety Day', date=datetime.date(2020, 10, 15)),
#  Holiday(name='World Food Day', date=datetime.date(2020, 10, 16)),
#  Holiday(name="Boss's Day", date=datetime.date(2020, 10, 16)),
#  Holiday(name='Navratri', date=datetime.date(2020, 10, 17)),
#  Holiday(name='International Day for the Eradication of Poverty', date=datetime.date(2020, 10, 17)),
#  Holiday(name='Sweetest Day', date=datetime.date(2020, 10, 17)),
#  Holiday(name='Alaska Day', date=datetime.date(2020, 10, 18)),
#  Holiday(name='Alaska Day observed', date=datetime.date(2020, 10, 19)),
#  Holiday(name='World Statistics Day', date=datetime.date(2020, 10, 20)),
#  Holiday(name='United Nations Day', date=datetime.date(2020, 10, 24)),
#  Holiday(name='World Development Information Day', date=datetime.date(2020, 10, 24)),
#  Holiday(name='Dussehra', date=datetime.date(2020, 10, 25)),
#  Holiday(name='World Day for Audiovisual Heritage', date=datetime.date(2020, 10, 27)),
#  Holiday(name="The Prophet's Birthday", date=datetime.date(2020, 10, 29)),
#  Holiday(name='World Stroke Day', date=datetime.date(2020, 10, 29)),
#  Holiday(name='Nevada Day', date=datetime.date(2020, 10, 30)),
#  Holiday(name='World Cities Day', date=datetime.date(2020, 10, 31)),
#  Holiday(name='Halloween', date=datetime.date(2020, 10, 31)),
#  Holiday(name="All Saints' Day", date=datetime.date(2020, 11, 1)),
#  Holiday(name='World Vegan Day', date=datetime.date(2020, 11, 1)),
#  Holiday(name='First Day of Native American Heritage Month', date=datetime.date(2020, 11, 1)),
#  Holiday(name='Daylight Saving Time ends', date=datetime.date(2020, 11, 1)),
#  Holiday(name="All Souls' Day", date=datetime.date(2020, 11, 2)),
#  Holiday(name='International Day to End Impunity for Crimes against Journalists', date=datetime.date(2020, 11, 2)),
#  Holiday(name='Election Day (General Election)', date=datetime.date(2020, 11, 3)),
#  Holiday(name='Election Day', date=datetime.date(2020, 11, 3)),
#  Holiday(name='Susan B. Anthony Day', date=datetime.date(2020, 11, 3)),
#  Holiday(name='World Tsunami Awareness Day', date=datetime.date(2020, 11, 5)),
#  Holiday(name='Return Day', date=datetime.date(2020, 11, 5)),
#  Holiday(name='International Day for Preventing the Exploitation of the Environment in War and Armed Conflict', date=datetime.date(2020, 11, 6)),
#  Holiday(name='Barack Obama Day', date=datetime.date(2020, 11, 9)),
#  Holiday(name='World Science Day for Peace and Development', date=datetime.date(2020, 11, 10)),
#  Holiday(name='Marine Corps Birthday', date=datetime.date(2020, 11, 10)),
#  Holiday(name='Veterans Day', date=datetime.date(2020, 11, 11)),
#  Holiday(name='World Pneumonia Day', date=datetime.date(2020, 11, 12)),
#  Holiday(name='Friday the 13th', date=datetime.date(2020, 11, 13)),
#  Holiday(name='Diwali/Deepavali', date=datetime.date(2020, 11, 14)),
#  Holiday(name='World Diabetes Day', date=datetime.date(2020, 11, 14)),
#  Holiday(name='World Day of Remembrance for Road Traffic Victims', date=datetime.date(2020, 11, 15)),
#  Holiday(name='International Day for Tolerance', date=datetime.date(2020, 11, 16)),
#  Holiday(name='World Prematurity Day', date=datetime.date(2020, 11, 17)),
#  Holiday(name='World Philosophy Day', date=datetime.date(2020, 11, 19)),
#  Holiday(name='World Toilet Day', date=datetime.date(2020, 11, 19)),
#  Holiday(name="International Men's Day", date=datetime.date(2020, 11, 19)),
#  Holiday(name='George Rogers Clark Day', date=datetime.date(2020, 11, 19)),
#  Holiday(name="Universal Children's Day", date=datetime.date(2020, 11, 20)),
#  Holiday(name='Africa Industrialization Day', date=datetime.date(2020, 11, 20)),
#  Holiday(name='World Television Day', date=datetime.date(2020, 11, 21)),
#  Holiday(name='International Day for the Elimination of Violence against Women', date=datetime.date(2020, 11, 25)),
#  Holiday(name='Thanksgiving Day', date=datetime.date(2020, 11, 26)),
#  Holiday(name='State Holiday', date=datetime.date(2020, 11, 27)),
#  Holiday(name="Presidents' Day", date=datetime.date(2020, 11, 27)),
#  Holiday(name="Lincoln's Birthday/Lincoln's Day", date=datetime.date(2020, 11, 27)),
#  Holiday(name='Day After Thanksgiving', date=datetime.date(2020, 11, 27)),
#  Holiday(name='Black Friday', date=datetime.date(2020, 11, 27)),
#  Holiday(name='American Indian Heritage Day', date=datetime.date(2020, 11, 27)),
#  Holiday(name='Native American Heritage Day', date=datetime.date(2020, 11, 27)),
#  Holiday(name='Native American Heritage Day', date=datetime.date(2020, 11, 27)),
#  Holiday(name='First Sunday of Advent', date=datetime.date(2020, 11, 29)),
#  Holiday(name='International Day of Solidarity with the Palestinian People', date=datetime.date(2020, 11, 29)),
#  Holiday(name="Nellie Tayloe Ross's Birthday", date=datetime.date(2020, 11, 29)),
#  Holiday(name='Day of Remembrance for all Victims of Chemical Warfare', date=datetime.date(2020, 11, 30)),
#  Holiday(name='Cyber Monday', date=datetime.date(2020, 11, 30)),
#  Holiday(name='World AIDS Day', date=datetime.date(2020, 12, 1)),
#  Holiday(name='Rosa Parks Day', date=datetime.date(2020, 12, 1)),
#  Holiday(name='Rosa Parks Day', date=datetime.date(2020, 12, 1)),
#  Holiday(name='Giving Tuesday', date=datetime.date(2020, 12, 1)),
#  Holiday(name='International Day for the Abolition of Slavery', date=datetime.date(2020, 12, 2)),
#  Holiday(name='International Day of Persons with Disabilities', date=datetime.date(2020, 12, 3)),
#  Holiday(name='International Day of Banks', date=datetime.date(2020, 12, 4)),
#  Holiday(name='International Volunteer Day for Economic and Social Development', date=datetime.date(2020, 12, 5)),
#  Holiday(name='World Soil Day', date=datetime.date(2020, 12, 5)),
#  Holiday(name='St Nicholas Day', date=datetime.date(2020, 12, 6)),
#  Holiday(name='International Civil Aviation Day', date=datetime.date(2020, 12, 7)),
#  Holiday(name='Pearl Harbor Remembrance Day', date=datetime.date(2020, 12, 7)),
#  Holiday(name='Pearl Harbor Remembrance Day', date=datetime.date(2020, 12, 7)),
#  Holiday(name='Delaware Day', date=datetime.date(2020, 12, 7)),
#  Holiday(name='Feast of the Immaculate Conception', date=datetime.date(2020, 12, 8)),
#  Holiday(name='International Anti-Corruption Day', date=datetime.date(2020, 12, 9)),
#  Holiday(name='World Genocide Commemoration Day', date=datetime.date(2020, 12, 9)),
#  Holiday(name='Human Rights Day', date=datetime.date(2020, 12, 10)),
#  Holiday(name='Wyoming Day', date=datetime.date(2020, 12, 10)),
#  Holiday(name='Chanukah/Hanukkah (first day)', date=datetime.date(2020, 12, 11)),
#  Holiday(name='International Mountain Day', date=datetime.date(2020, 12, 11)),
#  Holiday(name='International Day of Neutrality', date=datetime.date(2020, 12, 12)),
#  Holiday(name='International Universal Health Coverage Day', date=datetime.date(2020, 12, 12)),
#  Holiday(name='Feast of Our Lady of Guadalupe', date=datetime.date(2020, 12, 12)),
#  Holiday(name='National Guard Birthday', date=datetime.date(2020, 12, 13)),
#  Holiday(name='Bill of Rights Day', date=datetime.date(2020, 12, 15)),
#  Holiday(name='Pan American Aviation Day', date=datetime.date(2020, 12, 17)),
#  Holiday(name='Wright Brothers Day', date=datetime.date(2020, 12, 17)),
#  Holiday(name='Last Day of Chanukah', date=datetime.date(2020, 12, 18)),
#  Holiday(name='International Migrants Day', date=datetime.date(2020, 12, 18)),
#  Holiday(name='Arabic Language Day', date=datetime.date(2020, 12, 18)),
#  Holiday(name='International Human Solidarity Day', date=datetime.date(2020, 12, 20)),
#  Holiday(name='December Solstice', date=datetime.date(2020, 12, 21)),
#  Holiday(name='Christmas Eve', date=datetime.date(2020, 12, 24)),
#  Holiday(name='Christmas Eve', date=datetime.date(2020, 12, 24)),
#  Holiday(name='Christmas Eve', date=datetime.date(2020, 12, 24)),
#  Holiday(name="Washington's Birthday", date=datetime.date(2020, 12, 24)),
#  Holiday(name="Asarah B'Tevet", date=datetime.date(2020, 12, 25)),
#  Holiday(name='Christmas Day', date=datetime.date(2020, 12, 25)),
#  Holiday(name='Christmas Day', date=datetime.date(2020, 12, 25)),
#  Holiday(name='Kwanzaa (first day)', date=datetime.date(2020, 12, 26)),
#  Holiday(name='Day After Christmas Day', date=datetime.date(2020, 12, 26)),
#  Holiday(name='International Day of Epidemic Preparedness', date=datetime.date(2020, 12, 27)),
#  Holiday(name="New Year's Eve", date=datetime.date(2020, 12, 31)),
#  Holiday(name="New Year's Eve", date=datetime.date(2020, 12, 31)),
#  Holiday(name="New Year's Day", date=datetime.date(2021, 1, 1)),
#  Holiday(name="New Year's Day", date=datetime.date(2021, 1, 1)),
#  Holiday(name='World Braille Day', date=datetime.date(2021, 1, 4)),
#  Holiday(name='Epiphany', date=datetime.date(2021, 1, 6)),
#  Holiday(name='Orthodox Christmas Day', date=datetime.date(2021, 1, 7)),
#  Holiday(name="International Programmers' Day", date=datetime.date(2021, 1, 7)),
#  Holiday(name='Estelle Reel Day', date=datetime.date(2021, 1, 7)),
#  Holiday(name='Battle of New Orleans', date=datetime.date(2021, 1, 8)),
#  Holiday(name='Stephen Foster Memorial Day', date=datetime.date(2021, 1, 13)),
#  Holiday(name='Orthodox New Year', date=datetime.date(2021, 1, 14)),
#  Holiday(name='World Religion Day', date=datetime.date(2021, 1, 17)),
#  Holiday(name='Martin Luther King Jr. Day', date=datetime.date(2021, 1, 18)),
#  Holiday(name='Martin Luther King Jr. Day', date=datetime.date(2021, 1, 18)),
#  Holiday(name="Robert E. Lee's Birthday", date=datetime.date(2021, 1, 18)),
#  Holiday(name='Idaho Human Rights Day', date=datetime.date(2021, 1, 18)),
#  Holiday(name='Civil Rights Day', date=datetime.date(2021, 1, 18)),
#  Holiday(name="Robert E. Lee's Birthday", date=datetime.date(2021, 1, 19)),
#  Holiday(name='State Holiday', date=datetime.date(2021, 1, 19)),
#  Holiday(name="Confederate Heroes' Day", date=datetime.date(2021, 1, 19)),
#  Holiday(name='Inauguration Day', date=datetime.date(2021, 1, 20)),
#  Holiday(name='Inauguration Day', date=datetime.date(2021, 1, 20)),
#  Holiday(name='International Day of Education', date=datetime.date(2021, 1, 24)),
#  Holiday(name='International Customs Day', date=datetime.date(2021, 1, 26)),
#  Holiday(name='International Day of Commemoration in Memory of the Victims of the Holocaust', date=datetime.date(2021, 1, 27)),
#  Holiday(name="Tu Bishvat/Tu B'Shevat", date=datetime.date(2021, 1, 28)),
#  Holiday(name='Kansas Day', date=datetime.date(2021, 1, 29)),
#  Holiday(name='World Leprosy Day', date=datetime.date(2021, 1, 31)),
#  Holiday(name='National Freedom Day', date=datetime.date(2021, 2, 1)),
#  Holiday(name='First Day of Black History Month', date=datetime.date(2021, 2, 1)),
#  Holiday(name='World Wetlands Day', date=datetime.date(2021, 2, 2)),
# ...
#  Holiday(name='Truman Day', date=datetime.date(2021, 5, 8)),
#  Holiday(name='Victory in Europe Day', date=datetime.date(2021, 5, 8)),
#  Holiday(name="Mother's Day", date=datetime.date(2021, 5, 9)),
#  Holiday(name="Mother's Day", date=datetime.date(2021, 5, 9)),
#  Holiday(name='International Day of Argania', date=datetime.date(2021, 5, 10)),
#  Holiday(name='Confederate Memorial Day', date=datetime.date(2021, 5, 10)),
#  Holiday(name='Confederate Memorial Day', date=datetime.date(2021, 5, 10)),
#  Holiday(name='International Nurses Day', date=datetime.date(2021, 5, 12)),
#  Holiday(name='Ascension Day', date=datetime.date(2021, 5, 13)),
#  Holiday(name='Eid al-Fitr', date=datetime.date(2021, 5, 13)),
#  Holiday(name='Native American Day', date=datetime.date(2021, 5, 14)),
#  Holiday(name='International Day of Families', date=datetime.date(2021, 5, 15)),
#  Holiday(name='Public Lands Day', date=datetime.date(2021, 5, 15)),
#  Holiday(name='Peace Officers Memorial Day', date=datetime.date(2021, 5, 15)),
#  Holiday(name='Armed Forces Day', date=datetime.date(2021, 5, 15)),
#  Holiday(name='Preakness Stakes', date=datetime.date(2021, 5, 15)),
#  Holiday(name='International Day of Living Together in Peace', date=datetime.date(2021, 5, 16)),
#  Holiday(name='International Day of Light', date=datetime.date(2021, 5, 16)),
#  Holiday(name='Shavuot', date=datetime.date(2021, 5, 17)),
#  Holiday(name='World Telecommunication and Information Society Day', date=datetime.date(2021, 5, 17)),
#  Holiday(name='Tax Day', date=datetime.date(2021, 5, 17)),
#  Holiday(name='Emergency Medical Services for Children Day', date=datetime.date(2021, 5, 19)),
#  Holiday(name='World Bee Day', date=datetime.date(2021, 5, 20)),
#  Holiday(name='World Autoimmune / Autoinflammatory Arthritis Day', date=datetime.date(2021, 5, 20)),
#  Holiday(name='World Day for Cultural Diversity for Dialogue and Development', date=datetime.date(2021, 5, 21)),
#  Holiday(name='International Tea Day', date=datetime.date(2021, 5, 21)),
#  Holiday(name='National Defense Transportation Day', date=datetime.date(2021, 5, 21)),
#  Holiday(name='International Day for Biological Diversity', date=datetime.date(2021, 5, 22)),
#  Holiday(name='National Maritime Day', date=datetime.date(2021, 5, 22)),
#  Holiday(name='Harvey Milk Day', date=datetime.date(2021, 5, 22)),
#  Holiday(name='Pentecost', date=datetime.date(2021, 5, 23)),
#  Holiday(name='International Day to End Obstetric Fistula', date=datetime.date(2021, 5, 23)),
#  Holiday(name='Whit Monday', date=datetime.date(2021, 5, 24)),
#  Holiday(name='African Liberation Day', date=datetime.date(2021, 5, 25)),
#  Holiday(name="National Missing Children's Day", date=datetime.date(2021, 5, 25)),
#  Holiday(name='Day of Vesak', date=datetime.date(2021, 5, 26)),
#  Holiday(name='International Day of United Nations Peacekeepers', date=datetime.date(2021, 5, 29)),
#  Holiday(name='Trinity Sunday', date=datetime.date(2021, 5, 30)),
#  Holiday(name='World No Tobacco Day', date=datetime.date(2021, 5, 31)),
#  Holiday(name='Memorial Day', date=datetime.date(2021, 5, 31)),
#  Holiday(name='Decoration Day', date=datetime.date(2021, 5, 31)),
#  Holiday(name="Jefferson Davis' Birthday", date=datetime.date(2021, 5, 31)),
#  Holiday(name='Global Day of Parents', date=datetime.date(2021, 6, 1)),
#  Holiday(name='First Day of Pride Month', date=datetime.date(2021, 6, 1)),
#  Holiday(name='First Day of Caribbean-American Heritage Month', date=datetime.date(2021, 6, 1)),
#  Holiday(name='Statehood Day', date=datetime.date(2021, 6, 1)),
#  Holiday(name='Corpus Christi', date=datetime.date(2021, 6, 3)),
#  Holiday(name='World Bicycle Day', date=datetime.date(2021, 6, 3)),
#  Holiday(name="Jefferson Davis' Birthday", date=datetime.date(2021, 6, 3)),
#  Holiday(name='International Day of Innocent Children Victims of Aggression', date=datetime.date(2021, 6, 4)),
#  Holiday(name='World Environment Day', date=datetime.date(2021, 6, 5)),
#  Holiday(name='International Day for the Fight against Illegal, Unreported and Unregulated Fishing', date=datetime.date(2021, 6, 5)),
#  Holiday(name='Belmont Stakes', date=datetime.date(2021, 6, 5)),
#  Holiday(name='Day of the Russian Language', date=datetime.date(2021, 6, 6)),
#  Holiday(name='Native American Day', date=datetime.date(2021, 6, 6)),
#  Holiday(name='D-Day', date=datetime.date(2021, 6, 6)),
#  Holiday(name='World Food Safety Day', date=datetime.date(2021, 6, 7)),
#  Holiday(name="Jefferson Davis' Birthday", date=datetime.date(2021, 6, 7)),
#  Holiday(name='World Oceans Day', date=datetime.date(2021, 6, 8)),
#  Holiday(name='Kamehameha Day', date=datetime.date(2021, 6, 11)),
#  Holiday(name='World Day Against Child Labour', date=datetime.date(2021, 6, 12)),
#  Holiday(name='Loving Day', date=datetime.date(2021, 6, 12)),
#  Holiday(name='International Albinism Awareness Day', date=datetime.date(2021, 6, 13)),
#  Holiday(name='World Blood Donor Day', date=datetime.date(2021, 6, 14)),
#  Holiday(name='Army Birthday', date=datetime.date(2021, 6, 14)),
#  Holiday(name='Flag Day', date=datetime.date(2021, 6, 14)),
#  Holiday(name='World Elder Abuse Awareness Day', date=datetime.date(2021, 6, 15)),
#  Holiday(name='International Day of Family Remittances', date=datetime.date(2021, 6, 16)),
#  Holiday(name='World Day to Combat Desertification and Drought', date=datetime.date(2021, 6, 17)),
#  Holiday(name='Bunker Hill Day', date=datetime.date(2021, 6, 17)),
#  Holiday(name='Sustainable Gastronomy Day', date=datetime.date(2021, 6, 18)),
#  Holiday(name='Juneteenth (substitute)', date=datetime.date(2021, 6, 18)),
#  Holiday(name='Juneteenth National Freedom Day (substitute)', date=datetime.date(2021, 6, 18)),
#  Holiday(name='Juneteenth (substitute)', date=datetime.date(2021, 6, 18)),
#  Holiday(name='Juneteenth Day', date=datetime.date(2021, 6, 18)),
#  Holiday(name='International Day for the Elimination of Sexual Violence in Conflict', date=datetime.date(2021, 6, 19)),
#  Holiday(name='Juneteenth', date=datetime.date(2021, 6, 19)),
#  Holiday(name='Juneteenth', date=datetime.date(2021, 6, 19)),
#  Holiday(name='Juneteenth Day', date=datetime.date(2021, 6, 19)),
#  Holiday(name='Juneteenth National Freedom Day', date=datetime.date(2021, 6, 19)),
#  Holiday(name='Juneteenth', date=datetime.date(2021, 6, 19)),
#  Holiday(name='Juneteenth National Independence Day', date=datetime.date(2021, 6, 19)),
#  Holiday(name='Emancipation Day', date=datetime.date(2021, 6, 19)),
#  Holiday(name='World Refugee Day', date=datetime.date(2021, 6, 20)),
#  Holiday(name="Father's Day", date=datetime.date(2021, 6, 20)),
#  Holiday(name="Father's Day", date=datetime.date(2021, 6, 20)),
#  Holiday(name='West Virginia Day', date=datetime.date(2021, 6, 20)),
#  Holiday(name='American Eagle Day', date=datetime.date(2021, 6, 20)),
#  Holiday(name='June Solstice', date=datetime.date(2021, 6, 20)),
#  Holiday(name='International Day of Yoga', date=datetime.date(2021, 6, 21)),
#  Holiday(name='International Day of the Celebration of the Solstice', date=datetime.date(2021, 6, 21)),
#  Holiday(name='West Virginia Day observed', date=datetime.date(2021, 6, 21)),
#  Holiday(name='Public Service Day', date=datetime.date(2021, 6, 23)),
#  Holiday(name="International Widows' Day", date=datetime.date(2021, 6, 23)),
#  Holiday(name='Day of the Seafarer', date=datetime.date(2021, 6, 25)),
#  Holiday(name='International Day Against Drug Abuse and Illicit Trafficking', date=datetime.date(2021, 6, 26)),
#  Holiday(name='International Day in Support of Victims of Torture', date=datetime.date(2021, 6, 26)),
#  Holiday(name='Micro-, Small and Medium-sized Enterprises Day', date=datetime.date(2021, 6, 27)),
#  Holiday(name='Carolina Day', date=datetime.date(2021, 6, 28)),
#  Holiday(name='International Day of the Tropics', date=datetime.date(2021, 6, 29)),
#  Holiday(name='International Asteroid Day', date=datetime.date(2021, 6, 30)),
#  Holiday(name='International Day of Parliamentarism', date=datetime.date(2021, 6, 30)),
#  Holiday(name='International Day of Cooperatives', date=datetime.date(2021, 7, 3)),
#  Holiday(name='Independence Day', date=datetime.date(2021, 7, 4)),
#  Holiday(name='Independence Day', date=datetime.date(2021, 7, 4)),
#  Holiday(name='Independence Day (substitute)', date=datetime.date(2021, 7, 5)),
#  Holiday(name='Independence Day (substitute)', date=datetime.date(2021, 7, 5)),
#  Holiday(name='World Population Day', date=datetime.date(2021, 7, 11)),
#  Holiday(name='Nathan Bedford Forrest Day', date=datetime.date(2021, 7, 13)),
#  Holiday(name='Bastille Day', date=datetime.date(2021, 7, 14)),
#  Holiday(name='World Youth Skills Day', date=datetime.date(2021, 7, 15)),
#  Holiday(name='Rural Transit Day', date=datetime.date(2021, 7, 16)),
#  Holiday(name="Tisha B'Av", date=datetime.date(2021, 7, 18)),
#  Holiday(name='Nelson Mandela Day', date=datetime.date(2021, 7, 18)),
#  Holiday(name='Eid al-Adha', date=datetime.date(2021, 7, 20)),
#  Holiday(name='World Chess Day', date=datetime.date(2021, 7, 20)),
#  Holiday(name='Pioneer Day observed', date=datetime.date(2021, 7, 23)),
#  Holiday(name='Pioneer Day', date=datetime.date(2021, 7, 24)),
#  Holiday(name='World Drowning Prevention Day', date=datetime.date(2021, 7, 25)),
#  Holiday(name="Parents' Day", date=datetime.date(2021, 7, 25)),
#  Holiday(name='Korean War Veteran Recognition Day', date=datetime.date(2021, 7, 27)),
#  Holiday(name='National Korean War Veterans Armistice Day', date=datetime.date(2021, 7, 27)),
#  Holiday(name='World Hepatitis Day', date=datetime.date(2021, 7, 28)),
#  Holiday(name='International Day of Friendship', date=datetime.date(2021, 7, 30)),
#  Holiday(name='World Day Against Trafficking in Persons', date=datetime.date(2021, 7, 30)),
#  Holiday(name='Colorado Day', date=datetime.date(2021, 8, 1)),
#  Holiday(name='American Family Day', date=datetime.date(2021, 8, 1)),
#  Holiday(name='Coast Guard Birthday', date=datetime.date(2021, 8, 4)),
#  Holiday(name='Barack Obama Day', date=datetime.date(2021, 8, 4)),
#  Holiday(name='Purple Heart Day', date=datetime.date(2021, 8, 7)),
#  Holiday(name='Purple Heart Day', date=datetime.date(2021, 8, 7)),
#  Holiday(name="International Day of the World's Indigenous People", date=datetime.date(2021, 8, 9)),
#  Holiday(name='Victory Day', date=datetime.date(2021, 8, 9)),
#  Holiday(name='Muharram', date=datetime.date(2021, 8, 10)),
#  Holiday(name='International Youth Day', date=datetime.date(2021, 8, 12)),
#  Holiday(name='Friday the 13th', date=datetime.date(2021, 8, 13)),
#  Holiday(name='Assumption of Mary', date=datetime.date(2021, 8, 15)),
#  Holiday(name='National Navajo Code Talkers Day', date=datetime.date(2021, 8, 15)),
#  Holiday(name='National Senior Citizens Day', date=datetime.date(2021, 8, 15)),
#  Holiday(name='Bennington Battle Day', date=datetime.date(2021, 8, 16)),
#  Holiday(name='Ashura', date=datetime.date(2021, 8, 19)),
#  Holiday(name='World Humanitarian Day', date=datetime.date(2021, 8, 19)),
#  Holiday(name='National Aviation Day', date=datetime.date(2021, 8, 19)),
#  Holiday(name='Hawaii Statehood Day', date=datetime.date(2021, 8, 20)),
#  Holiday(name='Raksha Bandhan', date=datetime.date(2021, 8, 21)),
#  Holiday(name='International Day of Remembrance of and Tribute to the Victims of Terrorism', date=datetime.date(2021, 8, 21)),
#  Holiday(name='International Day Commemorating the Victims of Acts of Violence Based on Religion or Belief', date=datetime.date(2021, 8, 22)),
#  Holiday(name='International Day for the Remembrance of the Slave Trade and its Abolition', date=datetime.date(2021, 8, 23)),
#  Holiday(name='Susan B. Anthony Day', date=datetime.date(2021, 8, 26)),
#  Holiday(name="Women's Equality Day", date=datetime.date(2021, 8, 26)),
#  Holiday(name='Lyndon Baines Johnson Day', date=datetime.date(2021, 8, 27)),
#  Holiday(name='International Day against Nuclear Tests', date=datetime.date(2021, 8, 29)),
#  Holiday(name='International Day of the Victims of Enforced Disappearances', date=datetime.date(2021, 8, 30)),
#  Holiday(name='International Day for People of African Descent', date=datetime.date(2021, 8, 31)),
#  Holiday(name='International Overdose Awareness Day', date=datetime.date(2021, 8, 31)),
#  Holiday(name='World Sexual Health Day', date=datetime.date(2021, 9, 4)),
#  Holiday(name='International Day of Charity', date=datetime.date(2021, 9, 5)),
#  Holiday(name='Labor Day', date=datetime.date(2021, 9, 6)),
#  Holiday(name='Labor Day', date=datetime.date(2021, 9, 6)),
#  Holiday(name='Rosh Hashana', date=datetime.date(2021, 9, 7)),
#  Holiday(name='International Day of Clean Air for Blue Skies', date=datetime.date(2021, 9, 7)),
#  Holiday(name="Still's Disease Awareness Day", date=datetime.date(2021, 9, 7)),
#  Holiday(name='Rosh Hashana', date=datetime.date(2021, 9, 7)),
#  Holiday(name='International Literacy Day', date=datetime.date(2021, 9, 8)),
#  Holiday(name='International Day to Protect Education from Attack', date=datetime.date(2021, 9, 9)),
#  Holiday(name='California Admission Day', date=datetime.date(2021, 9, 9)),
#  Holiday(name='Ganesh Chaturthi', date=datetime.date(2021, 9, 10)),
#  Holiday(name='World Suicide Prevention Day', date=datetime.date(2021, 9, 10)),
#  Holiday(name='First Responders Day', date=datetime.date(2021, 9, 11)),
#  Holiday(name='Patriot Day', date=datetime.date(2021, 9, 11)),
#  Holiday(name='Patriot Day', date=datetime.date(2021, 9, 11)),
#  Holiday(name='Carl Garner Federal Lands Cleanup Day', date=datetime.date(2021, 9, 11)),
#  Holiday(name='Native American Day', date=datetime.date(2021, 9, 11)),
#  Holiday(name='International Day for South-South Cooperation', date=datetime.date(2021, 9, 12)),
#  Holiday(name='National Grandparents Day', date=datetime.date(2021, 9, 12)),
#  Holiday(name='Constitution Commemoration Day', date=datetime.date(2021, 9, 12)),
#  Holiday(name="International Programmers' Day", date=datetime.date(2021, 9, 13)),
#  Holiday(name='International Day of Democracy', date=datetime.date(2021, 9, 15)),
#  Holiday(name='First Day of National Hispanic Heritage Month', date=datetime.date(2021, 9, 15)),
#  Holiday(name='Yom Kippur', date=datetime.date(2021, 9, 16)),
#  Holiday(name='International Day for the Preservation of the Ozone Layer', date=datetime.date(2021, 9, 16)),
#  Holiday(name='Yom Kippur', date=datetime.date(2021, 9, 16)),
#  Holiday(name='World Patient Safety Day', date=datetime.date(2021, 9, 17)),
#  Holiday(name='Constitution Day and Citizenship Day', date=datetime.date(2021, 9, 17)),
#  Holiday(name='National POW/MIA Recognition Day', date=datetime.date(2021, 9, 17)),
#  Holiday(name='International Equal Pay Day', date=datetime.date(2021, 9, 18)),
#  Holiday(name='Air Force Birthday', date=datetime.date(2021, 9, 18)),
#  Holiday(name='National CleanUp Day', date=datetime.date(2021, 9, 18)),
#  Holiday(name='First Day of Sukkot', date=datetime.date(2021, 9, 21)),
#  Holiday(name='International Day of Peace', date=datetime.date(2021, 9, 21)),
#  Holiday(name='Emancipation Day', date=datetime.date(2021, 9, 22)),
#  Holiday(name='September Equinox', date=datetime.date(2021, 9, 22)),
#  Holiday(name='International Day of Sign Languages', date=datetime.date(2021, 9, 23)),
#  Holiday(name='International Celebrate Bisexuality Day', date=datetime.date(2021, 9, 23)),
#  Holiday(name='Native American Day', date=datetime.date(2021, 9, 24)),
#  Holiday(name='American Indian Heritage Day', date=datetime.date(2021, 9, 24)),
#  Holiday(name='Michigan Indian Day', date=datetime.date(2021, 9, 24)),
#  Holiday(name='Public Lands Day', date=datetime.date(2021, 9, 25)),
#  Holiday(name='National Public Lands Day', date=datetime.date(2021, 9, 25)),
#  Holiday(name='International Day for the Total Elimination of Nuclear Weapons', date=datetime.date(2021, 9, 26)),
#  Holiday(name="Gold Star Mother's Day", date=datetime.date(2021, 9, 26)),
#  Holiday(name='Last Day of Sukkot', date=datetime.date(2021, 9, 27)),
#  Holiday(name='World Tourism Day', date=datetime.date(2021, 9, 27)),
#  Holiday(name='American Indian Day', date=datetime.date(2021, 9, 27)),
#  Holiday(name='Shmini Atzeret', date=datetime.date(2021, 9, 28)),
#  Holiday(name='International Day for Universal Access to Information', date=datetime.date(2021, 9, 28)),
#  ...]

# %%
print(len(hday_list.innerHolidays))
# Out:
# 2823

# %%
for i in range(len(hday_list.innerHolidays)):
    print(hday_list.innerHolidays[i])
# Out:
# Margaret Thatcher Day (2021-01-10)
# World Sketchnote Day (2021-01-11)
# Zanzibar Revolution Day (2021-01-12)
# National Rubber Ducky Day (2021-01-13)
# Tamil Thai Pongdal Day (2021-01-14)
# National Bagel Day (2021-01-15)
# Signing of the Peace Accords (2021-01-16)
# New Year's Day (2020-01-01)
# World Braille Day (2020-01-04)
# Epiphany (2020-01-06)
# Asarah B'Tevet (2020-01-07)
# Orthodox Christmas Day (2020-01-07)
# International Programmers' Day (2020-01-07)
# Estelle Reel Day (2020-01-07)
# Battle of New Orleans (2020-01-08)
# Stephen Foster Memorial Day (2020-01-13)
# Orthodox New Year (2020-01-14)
# Lee-Jackson Day (2020-01-17)
# World Religion Day (2020-01-19)
# Robert E. Lee's Birthday (2020-01-19)
# State Holiday (2020-01-19)
# Confederate Heroes' Day (2020-01-19)
# Martin Luther King Jr. Day (2020-01-20)
# Robert E. Lee's Birthday (2020-01-20)
# Idaho Human Rights Day (2020-01-20)
# Civil Rights Day (2020-01-20)
# International Day of Education (2020-01-24)
# Lunar New Year (2020-01-25)
# International Customs Day (2020-01-26)
# World Philosophy Day (2024-11-21)
# International Day for the Elimination of Violence against Women (2024-11-25)
# Thanksgiving Day (2024-11-28)
# Thanksgiving Day (2024-11-28)
# International Day of Solidarity with the Palestinian People (2024-11-29)
# Nellie Tayloe Ross's Birthday (2024-11-29)
# State Holiday (2024-11-29)
# Presidents' Day (2024-11-29)
# Lincoln's Birthday/Lincoln's Day (2024-11-29)
# Day After Thanksgiving (2024-11-29)
# Black Friday (2024-11-29)
# American Indian Heritage Day (2024-11-29)
# Native American Heritage Day (2024-11-29)
# Native American Heritage Day (2024-11-29)
# Day of Remembrance for all Victims of Chemical Warfare (2024-11-30)
# First Sunday of Advent (2024-12-01)
# World AIDS Day (2024-12-01)
# Rosa Parks Day (2024-12-01)
# Rosa Parks Day (2024-12-01)
# International Day for the Abolition of Slavery (2024-12-02)
# Cyber Monday (2024-12-02)
# International Day of Persons with Disabilities (2024-12-03)
# Giving Tuesday (2024-12-03)
# International Day of Banks (2024-12-04)
# International Volunteer Day for Economic and Social Development (2024-12-05)
# World Soil Day (2024-12-05)
# St Nicholas Day (2024-12-06)
# International Civil Aviation Day (2024-12-07)
# Pearl Harbor Remembrance Day (2024-12-07)
# Pearl Harbor Remembrance Day (2024-12-07)
# Delaware Day (2024-12-07)
# Feast of the Immaculate Conception (2024-12-09)
# International Anti-Corruption Day (2024-12-09)
# World Genocide Commemoration Day (2024-12-09)
# Human Rights Day (2024-12-10)
# Wyoming Day (2024-12-10)
# International Mountain Day (2024-12-11)
# International Day of Neutrality (2024-12-12)
# International Universal Health Coverage Day (2024-12-12)
# Feast of Our Lady of Guadalupe (2024-12-12)
# Friday the 13th (2024-12-13)
# National Guard Birthday (2024-12-13)
# Bill of Rights Day (2024-12-15)
# Pan American Aviation Day (2024-12-17)
# Wright Brothers Day (2024-12-17)
# International Migrants Day (2024-12-18)
# Arabic Language Day (2024-12-18)
# International Human Solidarity Day (2024-12-20)
# December Solstice (2024-12-21)
# Christmas Eve (2024-12-24)
# Christmas Eve (2024-12-24)
# Christmas Day (2024-12-25)
# Christmas Day (2024-12-25)
# Chanukah/Hanukkah (first day) (2024-12-26)
# Kwanzaa (first day) (2024-12-26)
# Day After Christmas Day (2024-12-26)
# International Day of Epidemic Preparedness (2024-12-27)
# New Year's Eve (2024-12-31)
# New Year's Eve (2024-12-31)

# %%
# from datetime import datetime
# # Scrape Holidays from https://www.timeanddate.com/holidays/us/ 
# days = []
# dates = []
# years = ['2020', '2021', '2022', '2023', '2024']
# for year in years:
#     url_list = [f'https://www.timeanddate.com/holidays/us/{year}']
#     for i in range(len(url_list)):
#         r = requests.get(url_list[i])
#         soup = BeautifulSoup(r.text, 'html.parser')
#         table = soup.find('table', attrs = {'id':'holidays-table'})
#         body = table.find('tbody')
#         rows = body.find_all('tr')
#         for row in rows:
#             daywrappers = row.find_all('td')
#             datewrappers = row.find_all('th')
#             if datewrappers != []:
#                 date = datewrappers[0].get_text()
#                 date_string = f"{date}, {year}"
#                 fdatetime = datetime.strptime(date_string, "%b %d, %Y")
#                 fdate = datetime.date(fdatetime)
#                 dates.append(fdate)
# #                 print(fdate)
#             if daywrappers != []:
#                 dayname = daywrappers[1].get_text()
# #                 print(dayname)
#                 days.append(dayname)
       
# scraped = zip(days, dates)
# scrapedlist = (list(scraped))
# for i in scrapedlist:
#     hday_list.addHoliday(i)





# # hday_list.addHoliday(day)
#         # Remember, 2 previous years, current year, and 2  years into the future. You can scrape multiple years by adding year to the timeanddate URL. For example https://www.timeanddate.com/holidays/us/2022
#         # Check to see if name and date of holiday is in innerHolidays array
#         # Add non-duplicates to innerHolidays
#         # Handle any exceptions.

# %%
# scraped = zip(days, dates)
# list(scraped)

# %%
# Out:
# '0'

# %%
valid = False
viewYear = int(input("What year?\n"))
while viewYear not in range(2020,2025):
    viewYear = int(input("Not in range, please input year from 2020 to 2024.\n"))
while valid == False:
    viewWeek = input("What week? (1-52, leave blank for the current week)\n")
    if viewWeek == "":
        print("Showing current week.")
        valid = True
    elif int(viewWeek) in (range(1,53)):  
        print(f"Showing week {viewWeek}'s holidays.")
        valid = True
        hday_list.filter_holidays_by_week(viewYear, viewWeek)
    else:
        print("Not a valid input. Input a week from 1-52 or leave blank for the current week.")
# Out:
# What year?
# 2022
# What week? (1-52, leave blank for the current week)
# 2
# Showing week 2's holidays.

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[162], line 4
#       2 for i in hday_list.innerHolidays:
#       3     idate = i.date
# ----> 4     weekdate = idate.isocalendar
#       5     if weekdate in (int(year), int(week_number), range(1,8)):
#       6         holidayList.append(i)
#
# AttributeError: 'str' object has no attribute 'isocalendar'

# %%
# Out:
# 2021
# 01
# 10
# 2021
# 01
# 11
# 2021
# 01
# 12
# 2021
# 01
# 13
# 2021
# 01
# 14
# 2021
# 01
# 15
# 2021
# 01
# 16
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[177], line 2
#       1 for i in hday_list.innerHolidays:
# ----> 2     print (i.date[0:4])
#       3     print (i.date[5:7])
#       4     print (i.date[8:10])
#
# TypeError: 'datetime.date' object is not subscriptable

# %%
today = datetime.date.today()
print(today.isocalendar())
# Out:
# datetime.IsoCalendarDate(year=2022, week=50, weekday=7)

# %%
weekdateList = []
holidayList = []
for i in hday_list.innerHolidays:
    idate = i.date
    try:
        weekdate = idate.isocalendar()
    except:
        exceptYear = (i.date[0:4])
        exceptMonth = (i.date[5:7])
        exceptDay = (i.date[8:10])
        exceptDate = datetime.date(int(exceptYear),int(exceptMonth),int(exceptDay))
        weekdate = exceptDate.isocalendar()
    weekdateList.append(weekdate)
    for w in range(len(weekdateList)):              
        print(weekdateList[w])
        if w in datetime.IsoCalendarDate(year=int("2022"), week=int("2"), weekday=range(1,8)):
            holidayList.append(i)
            
for holiday in holidayList:
    print(str(holiday))
# Out:
# datetime.IsoCalendarDate(year=2021, week=1, weekday=7)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[243], line 16
#      14     for w in range(len(weekdateList)):
#      15         print(weekdateList[w])
# ---> 16         if w in datetime.IsoCalendarDate(year=int("2022"), week=int("2"), weekday=range(1,8)):
#      17             holidayList.append(i)
#      19 for holiday in holidayList:
#
# AttributeError: module 'datetime' has no attribute 'IsoCalendarDate'

# %%
weekdateList = []
holidayList = []
for i in hday_list.innerHolidays:
    idate = i.date
    try:
        weekdate = idate.isocalendar()
    except:
        exceptYear = (i.date[0:4])
        exceptMonth = (i.date[5:7])
        exceptDay = (i.date[8:10])
        exceptDate = datetime.date(int(exceptYear),int(exceptMonth),int(exceptDay))
        weekdate = exceptDate.isocalendar()
    weekdateList.append(weekdate)
    for w in range(len(weekdateList)):              
#         print(weekdateList[w])
        if w in (int("2022"), int("2"), range(1,8)):
            holidayList.append(i)
            
for holiday in holidayList:
    print(str(holiday))
# Out:
# Zanzibar Revolution Day (2021-01-12)
# National Rubber Ducky Day (2021-01-13)
# Tamil Thai Pongdal Day (2021-01-14)
# National Bagel Day (2021-01-15)
# Signing of the Peace Accords (2021-01-16)
# New Year's Day (2020-01-01)
# World Braille Day (2020-01-04)
# Epiphany (2020-01-06)
# Asarah B'Tevet (2020-01-07)
# Orthodox Christmas Day (2020-01-07)
# International Programmers' Day (2020-01-07)
# Estelle Reel Day (2020-01-07)
# Battle of New Orleans (2020-01-08)
# Stephen Foster Memorial Day (2020-01-13)
# Orthodox New Year (2020-01-14)
# Lee-Jackson Day (2020-01-17)
# World Religion Day (2020-01-19)
# Robert E. Lee's Birthday (2020-01-19)
# State Holiday (2020-01-19)
# Confederate Heroes' Day (2020-01-19)
# Martin Luther King Jr. Day (2020-01-20)
# Robert E. Lee's Birthday (2020-01-20)
# Idaho Human Rights Day (2020-01-20)
# Civil Rights Day (2020-01-20)
# International Day of Education (2020-01-24)
# Lunar New Year (2020-01-25)
# International Customs Day (2020-01-26)
# World Leprosy Day (2020-01-26)
# International Day of Commemoration in Memory of the Victims of the Holocaust (2020-01-27)
# Kansas Day (2020-01-29)
# National Freedom Day (2020-02-01)
# First Day of Black History Month (2020-02-01)
# World Wetlands Day (2020-02-02)
# Groundhog Day (2020-02-02)
# Super Bowl (2020-02-02)
# World Cancer Day (2020-02-04)
# Rosa Parks Day (2020-02-04)
# Rosa Parks Day (2020-02-04)
# National Girls and Women in Sports Day (2020-02-05)
# International Day of Zero Tolerance for Female Genital Mutilation (2020-02-06)
# Ronald Reagan Day (2020-02-06)
# National Wear Red Day (2020-02-07)
# Tu Bishvat/Tu B'Shevat (2020-02-10)
# World Pulses Day (2020-02-10)
# International Day of Women and Girls in Science (2020-02-11)
# World Day of the Sick (2020-02-11)
# Lincoln's Birthday (2020-02-12)
# Lincoln's Birthday (2020-02-12)
# Georgia Day (2020-02-12)
# World Radio Day (2020-02-13)
# Valentine's Day (2020-02-14)
# Statehood Day (2020-02-14)
# Susan B. Anthony's Birthday (2020-02-15)
# Elizabeth Peratrovich Day (2020-02-16)
# Presidents' Day (2020-02-17)
# Presidents' Day (2020-02-17)
# Presidents' Day (2020-02-17)
# Daisy Gatson Bates Day (2020-02-17)
# World Day of Social Justice (2020-02-20)
# Maha Shivaratri (2020-02-21)
# International Mother Language Day (2020-02-21)
# African-American Scientist and Inventor Day (2020-02-25)
# Shrove Tuesday/Mardi Gras (2020-02-25)
# Shrove Tuesday/Mardi Gras (2020-02-25)
# Arabic Language Day (2024-12-18)
# Arabic Language Day (2024-12-18)
# International Human Solidarity Day (2024-12-20)
# International Human Solidarity Day (2024-12-20)
# December Solstice (2024-12-21)
# December Solstice (2024-12-21)
# Christmas Eve (2024-12-24)
# Christmas Eve (2024-12-24)
# Christmas Eve (2024-12-24)
# Christmas Eve (2024-12-24)
# Christmas Day (2024-12-25)
# Christmas Day (2024-12-25)
# Christmas Day (2024-12-25)
# Christmas Day (2024-12-25)
# Chanukah/Hanukkah (first day) (2024-12-26)
# Chanukah/Hanukkah (first day) (2024-12-26)
# Kwanzaa (first day) (2024-12-26)
# Kwanzaa (first day) (2024-12-26)
# Day After Christmas Day (2024-12-26)
# Day After Christmas Day (2024-12-26)
# International Day of Epidemic Preparedness (2024-12-27)
# International Day of Epidemic Preparedness (2024-12-27)
# New Year's Eve (2024-12-31)
# New Year's Eve (2024-12-31)
# New Year's Eve (2024-12-31)
# New Year's Eve (2024-12-31)

# %%
weekdateList = []
holidayList = []
for i in hday_list.innerHolidays:
    idate = i.date
    try:
        weekdate = idate.isocalendar()
    except:
        exceptYear = (i.date[0:4])
        exceptMonth = (i.date[5:7])
        exceptDay = (i.date[8:10])
        exceptDate = datetime.date(int(exceptYear),int(exceptMonth),int(exceptDay))
        weekdate = exceptDate.isocalendar()
    weekdateList.append(weekdate)
    yr, wk, wkday = weekdate
    if yr == 2022 and wk == 2 and wkday in range(1,8):
        holidayList.append(i)
            
for holiday in holidayList:
    print(str(holiday))
# Out:
# Stephen Foster Memorial Day (2022-01-13)
# Orthodox New Year (2022-01-14)
# World Religion Day (2022-01-16)

# %%
    def viewCurrentWeek(self):
        # Use the Datetime Module to look up current week and year
        today = datetime.date.today().isocalendar
        tyr, twk, twkday = today
        self.filter_holidays_by_week(tyr, twk)

        # Use your filter_holidays_by_week function to get the list of holidays 
        # for the current week/year
        # Use your displayHolidaysInWeek function to display the holidays in the week
        # Ask user if they want to get the weather
        # If yes, use your getWeather function and display results
        pass
    
        def filter_holidays_by_week(self, year, week_number):
        global holidayList
        global weekdateList
        weekdateList = []
        holidayList = []
        for i in self.innerHolidays:
            idate = i.date
            try:
                weekdate = idate.isocalendar()
            except:
                exceptYear = (i.date[0:4])
                exceptMonth = (i.date[5:7])
                exceptDay = (i.date[8:10])
                exceptDate = datetime.date(int(exceptYear),int(exceptMonth),int(exceptDay))
                weekdate = exceptDate.isocalendar()
            weekdateList.append(weekdate)
            yr, wk, wkday = weekdate
            if yr == int(year) and wk == int(week_number) and wkday in range(1,8):
                holidayList.append(i)
        # Use a Lambda function to filter by week number and save this as holidays, use the filter on innerHolidays
        # Week number is part of the the Datetime object
        # Cast filter results as list
        # return your holidays
        self.displayHolidaysInWeek(holidayList)

        
# for i in range(len(hday_list.innerHolidays)):
#     print(hday_list.innerHolidays[i])
    

    def displayHolidaysInWeek(self, holidayList):
        # Use your filter_holidays_by_week to get list of holidays within a week as a parameter
        # Output formated holidays in the week. 
        # * Remember to use the holiday __str__ method.
        for holiday in holidayList:
            print(str(holiday))
